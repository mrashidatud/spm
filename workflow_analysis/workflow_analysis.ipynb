# %% [markdown]
# # Workflow Analysis - DDMD
#
# This notebook provides a simplified interface to the workflow analysis using modular Python scripts.
#
# ## Overview
# The analysis process includes:
# 1. Loading workflow data from datalife statistics
# 2. Estimating transfer rates using 4D interpolation from IOR benchmark data
# 3. Calculating Storage Performance Metrics (SPM) for different storage configurations
# 4. Generating visualizations and recommendations

# %%
# Import required libraries and modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os

# Import our workflow analysis modules
from modules.workflow_config import DEFAULT_WF, TEST_CONFIGS, STORAGE_LIST
from modules.workflow_data_utils import (
    load_workflow_data, calculate_io_time_breakdown
)
from modules.workflow_interpolation import (
    estimate_transfer_rates_for_workflow, calculate_aggregate_filesize_per_node
)
from modules.workflow_spm_calculator import (
    calculate_spm_for_workflow, filter_storage_options,
    display_top_sorted_averaged_rank, select_best_storage_and_parallelism
)
from modules.workflow_visualization import plot_all_visualizations

from modules.workflow_data_staging import insert_data_staging_rows

print("Modules imported successfully!")
# Out:
# Modules imported successfully!

# %% [markdown]
# ## Configuration
#
# Set the workflow to analyze and other parameters.

# %%
# Configuration
WORKFLOW_NAME = "1kg"  # Change this to analyze different workflows
IOR_DATA_PATH = "../perf_profiles/updated_master_ior_df.csv"

print(f"Analyzing workflow: {WORKFLOW_NAME}")
print(f"Available workflows: {list(TEST_CONFIGS.keys())}")
print(f"IOR data path: {IOR_DATA_PATH}")

ALLOWED_PARALLELISM = TEST_CONFIGS[WORKFLOW_NAME]["ALLOWED_PARALLELISM"]
# Out:
# Analyzing workflow: 1kg
# Available workflows: ['ddmd_2n_s', 'ddmd_4n_l', '1kg', '1kg_2', 'pyflex_240f', 'pyflex_s9_48f', 'ptychonn', 'montage', 'seismology', 'llm_wf', 'template_workflow']
# IOR data path: ../perf_profiles/updated_master_ior_df.csv

# %% [markdown]
# ## Step 1: Load Workflow Data
#
# Load and process the workflow data from datalife statistics.

# %%
# Load workflow data
print("Loading workflow data...")
wf_df, task_order_dict, all_wf_dict = load_workflow_data(WORKFLOW_NAME, debug=False)

print(f"\nWorkflow data loaded:")
print(f"- Total records: {len(wf_df)}")
print(f"- Task definitions: {len(task_order_dict)}")
print(f"- Unique tasks: {list(wf_df['taskName'].unique())}")
print(f"- Stages: {sorted(wf_df['stageOrder'].unique())}")
# Out:
# Loading workflow data...
# Trial folders: ['./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1']
# blk_files count: 1810
# datalife_monitor count: 1070
# target_tasks: ['13757-dc026', '13765-dc026', '13895-dc026', '13912-dc026', '13926-dc026', '13927-dc026', '13937-dc026', '13973-dc026', '13976-dc026', '14253-dc026', '14383-dc026', '14542-dc026', '14648-dc026', '14738-dc026', '14972-dc026', '14977-dc026', '14980-dc026', '14988-dc026', '14998-dc026', '15007-dc026', '15023-dc026', '15025-dc026', '15028-dc026', '15029-dc026', '15031-dc026', '15033-dc026', '15035-dc026', '15037-dc026', '15039-dc026', '15041-dc026', '15816-dc177', '15818-dc177', '15820-dc177', '15873-dc177', '15876-dc177', '15918-dc026', '15919-dc026', '15921-dc177', '15948-dc177', '15950-dc026', '15980-dc177', '15985-dc177', '15987-dc177', '15989-dc177', '15991-dc177', '15993-dc177', '15995-dc177', '15997-dc177', '15999-dc177', '16001-dc177', '16003-dc177', '16005-dc177', '16008-dc177', '16009-dc177', '16011-dc177', '16013-dc177', '16015-dc177', '16017-dc177', '16019-dc177', '16021-dc177', '16023-dc177', '16032-dc177', '16040-dc177', '16490-dc177', '16492-dc177', '16503-dc177', '17508-dc177', '17520-dc177', '17526-dc026', '17538-dc177', '17546-dc026', '17556-dc177', '17559-dc177', '17561-dc177', '17563-dc177', '17565-dc177', '17567-dc177', '17570-dc177', '17571-dc177', '17573-dc177', '17576-dc177', '17578-dc177', '17652-dc026', '17781-dc026', '17782-dc026', '17786-dc026', '17851-dc026', '17869-dc026', '17870-dc026', '17872-dc026', '17874-dc026', '17876-dc026', '17878-dc026', '17880-dc026', '1900-dc148', '1903-dc148', '1906-dc148', '1909-dc148', '1940-dc148', '194433-dc273', '194452-dc273', '194456-dc273', '194457-dc273', '194458-dc273', '194525-dc273', '194557-dc273', '194563-dc273', '194576-dc273', '194583-dc273', '194623-dc273', '194625-dc273', '194627-dc273', '194629-dc273', '194631-dc273', '194633-dc273', '194635-dc273', '194637-dc273', '194639-dc273', '194641-dc273', '194643-dc273', '194645-dc273', '194647-dc273', '194649-dc273', '194651-dc273', '194653-dc273', '194655-dc273', '194657-dc273', '194660-dc273', '194661-dc273', '194914-dc260', '194924-dc260', '194926-dc260', '194928-dc260', '194930-dc260', '194932-dc260', '194934-dc260', '195006-dc260', '195023-dc260', '195030-dc260', '195053-dc260', '195083-dc260', '195086-dc260', '195088-dc260', '195090-dc260', '195092-dc260', '195094-dc260', '195097-dc260', '195099-dc260', '195101-dc260', '195103-dc260', '195105-dc260', '195107-dc260', '195109-dc260', '195109-dc273', '195111-dc260', '195111-dc273', '195113-dc260', '195115-dc260', '195117-dc260', '195119-dc260', '195121-dc260', '195129-dc273', '195581-dc260', '195582-dc260', '195591-dc260', '1958-dc148', '196116-dc273', '196118-dc273', '196135-dc273', '196142-dc273', '196149-dc273', '196152-dc273', '196166-dc273', '196173-dc273', '196183-dc273', '196185-dc273', '196187-dc273', '196189-dc273', '196191-dc273', '196193-dc273', '1963-dc148', '1965-dc148', '196580-dc260', '196591-dc260', '196621-dc260', '196637-dc260', '196639-dc260', '196641-dc260', '196643-dc260', '196645-dc260', '196647-dc260', '196649-dc260', '196651-dc260', '196653-dc260', '196657-dc260', '196658-dc260', '1968-dc148', '1970-dc148', '1972-dc148', '1974-dc148', '1977-dc148', '1978-dc148', '24989-dc135', '24992-dc135', '25009-dc135', '25020-dc135', '25026-dc135', '25051-dc135', '25078-dc135', '25084-dc135', '25087-dc135', '25106-dc135', '25128-dc135', '25140-dc135', '25142-dc135', '25146-dc135', '25147-dc135', '25149-dc135', '25151-dc135', '25153-dc135', '25155-dc135', '25163-dc135', '25165-dc135', '25166-dc135', '25168-dc135', '25170-dc135', '25172-dc135', '25174-dc135', '25176-dc135', '25179-dc135', '25181-dc135', '25182-dc135', '25630-dc135', '25632-dc135', '25645-dc135', '26649-dc135', '26657-dc135', '26688-dc135', '26698-dc135', '26700-dc135', '26702-dc135', '26704-dc135', '26706-dc135', '26708-dc135', '26710-dc135', '26712-dc135', '26714-dc135', '26716-dc135', '26718-dc135', '28352-dc257', '28372-dc257', '28374-dc257', '28376-dc257', '28440-dc257', '28461-dc257', '28488-dc257', '28505-dc257', '28542-dc257', '28547-dc257', '28549-dc257', '2855 ...
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6818-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6818-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25051-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25051-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28580-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28580-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25170-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25170-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194433-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194433-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41406-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41406-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28562-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28562-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194456-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194456-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8352-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8352-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41420-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41420-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195099-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195099-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.32974-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.32974-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17556-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17556-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194926-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.194926-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196647-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196647-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6826-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6826-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15997-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15997-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17786-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17786-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196643-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196643-dc260.local.r_blk_trace.json
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_data_utils.py:238: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   wf_df = pd.concat([wf_df, new_row], ignore_index=True)
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65447-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65447-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65532-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65532-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196118-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196118-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25149-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25149-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194452-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194452-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15873-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15873-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.195109-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/SIFT.chr10.vcf.195109-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr3n.tar.gz.26700-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr3.txt.26700-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30109-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30109-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31366-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31366-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.312-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.312-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33028-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33028-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31483-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31483-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194647-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194647-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30115-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30115-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15876-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15876-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39875-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39875-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17878-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17878-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.40333-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/SIFT.chr4.vcf.40333-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25174-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25174-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.16492-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/SIFT.chr7.vcf.16492-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6798-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6798-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195097-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195097-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31491-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31491-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30121-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30121-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196621-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196621-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194623-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194623-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31495-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31495-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28555-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28555-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28582-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28582-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39870-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39870-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25176-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25176-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65483-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65483-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28542-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28542-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196183-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196183-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.32999-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.32999-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28372-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28372-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39752-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39752-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196189-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196189-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196641-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196641-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195086-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195086-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195109-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195109-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr3n.tar.gz.26714-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr3.txt.26714-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6811-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6811-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33031-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33031-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195101-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195101-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17561-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17561-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.845-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33026-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33026-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8378-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8378-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28376-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28376-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195105-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195105-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194639-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194639-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194661-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194661-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8382-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8382-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.40348-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.14542-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.14542-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-3401-3601.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-3001-3201.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-1801-2001.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-4201-4401.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-201-401.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-4001-4201.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-5801-6001.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-1201-1401.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-4401-4601.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-2201-2401.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-1001-1201.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-1-201.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-3801-4001.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-5401-5601.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-5001-5201.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-1401-1601.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-1601-1801.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-3601-3801.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-401-601.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-5201-5401.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-3201-3401.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-5601-5801.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-601-801.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-2401-2601.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-801-1001.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-4801-5001.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-2001-2201.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-4601-4801.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-2801-3001.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n-2601-2801.tar.gz.195111-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65509-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65509-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39787-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39787-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31393-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31393-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.322-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.322-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31487-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31487-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30086-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30086-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39868-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39868-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15980-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15980-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6854-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6854-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17872-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17872-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.13912-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.13912-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25142-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25142-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65370-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65370-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6839-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6839-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33016-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33016-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8361-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8361-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17570-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17570-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25106-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25106-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194631-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194631-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28560-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28560-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15816-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15816-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30127-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30127-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39716-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39716-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.16021-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16021-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.14988-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.14988-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31291-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31291-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.24992-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.24992-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.16001-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16001-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.29050-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/SIFT.chr8.vcf.29050-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30107-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30107-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.7319-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8325-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8325-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6824-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6824-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-5401-5601.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-3401-3601.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-2401-2601.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-2601-2801.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-601-801.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-3601-3801.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-201-401.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-5801-6001.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-1601-1801.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-1-201.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-401-601.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-801-1001.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-1201-1401.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-5001-5201.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-5201-5401.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-3001-3201.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-2801-3001.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-5601-5801.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-3801-4001.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-4801-5001.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-4201-4401.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-1001-1201.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-4601-4801.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-3201-3401.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-1401-1601.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-4001-4201.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-2201-2401.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-2001-2201.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-1801-2001.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n-4401-4601.tar.gz.16490-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.32931-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.32931-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65437-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65437-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17874-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17874-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195117-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195117-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196187-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196187-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39766-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39766-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39890-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39890-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194525-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194525-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30125-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30125-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31479-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31479-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194657-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194657-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195083-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195083-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6686-dc111.local.r_blk_trace.json
# ...
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-1601-1801.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-3801-4001.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-2801-3001.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-5801-6001.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-3001-3201.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-5401-5601.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-1001-1201.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-2201-2401.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-1801-2001.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-401-601.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-5601-5801.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-201-401.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-4801-5001.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-3201-3401.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-2401-2601.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-601-801.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-5201-5401.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n-4401-4601.tar.gz.40335-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30073-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30073-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39773-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39773-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17565-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17565-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6764-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6764-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17880-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17880-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194649-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194649-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.32976-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.32976-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.31380-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31380-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8371-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8371-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.15007-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15007-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41338-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41338-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28576-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28576-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25084-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25084-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39884-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39884-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195121-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195121-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25165-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25165-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16017-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.16017-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.14972-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.14972-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25153-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25153-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17573-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17573-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33022-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33022-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28572-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28572-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39837-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39837-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15025-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.15025-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33018-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33018-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6743-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6743-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17870-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17870-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25020-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25020-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196149-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196149-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195103-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.195103-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.13926-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.13926-dc026.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.25163-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25163-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.16005-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16005-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39876-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39876-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194627-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194627-dc273.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.39880-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39880-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28558-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28558-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.6831-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6831-dc111.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.194914-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.194914-dc260.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41413-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41413-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28584-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28584-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33024-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33024-dc155.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.65418-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65418-dc148.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr3n.tar.gz.26688-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr3.txt.26688-dc135.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.28570-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28570-dc257.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15820-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/columns.txt.15820-dc177.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41360-dc146.local.r_blk_trace.json
# Detected random write pattern in file: ./1kgenome/par_6000_10n_nfs_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41360-dc146.local.r_blk_trace.json

# %%
# Display first few rows
print("\nFirst few rows of workflow data:")
print(wf_df.head())
print(wf_df.columns)
# Out:
# First few rows of workflow data:
#    operation  randomOffset  transferSize  aggregateFilesizeMB  numTasks  \
# 0          0             0  81791.000000             0.078002       300
# 1          0             0  81791.000000             0.078002       300
# 2          0             0  81791.000000             0.078002       300
# 3          1             1   8191.921474          2421.758036       300
# 4          1             1   8191.921474          2421.758036       300
#
#    parallelism  totalTime numNodesList  numNodes  tasksPerNode        trMiB  \
# 0          300   0.000049   [2, 5, 10]         2           150  1593.503085
# 1          300   0.000049   [2, 5, 10]         5            60  1593.503085
# 2          300   0.000049   [2, 5, 10]        10            30  1593.503085
# 3          300  19.632952   [2, 5, 10]         2           150   123.351699
# 4          300  19.632952   [2, 5, 10]         5            60   123.351699
#
#    storageType  opCount     taskName     taskPID                fileName  \
# 0            5        1  individuals  6818-dc111  chr2n-2201-2401.tar.gz
# 1            5        1  individuals  6818-dc111  chr2n-2201-2401.tar.gz
# 2            5        1  individuals  6818-dc111  chr2n-2201-2401.tar.gz
# 3            5   309988  individuals  6818-dc111     ALL.chr2.250000.vcf
# 4            5   309988  individuals  6818-dc111     ALL.chr2.250000.vcf
#
#    stageOrder      prevTask
# 0           1
# 1           1
# 2           1
# 3           1  initial_data
# 4           1  initial_data
# Index(['operation', 'randomOffset', 'transferSize', 'aggregateFilesizeMB',
#        'numTasks', 'parallelism', 'totalTime', 'numNodesList', 'numNodes',
#        'tasksPerNode', 'trMiB', 'storageType', 'opCount', 'taskName',
#        'taskPID', 'fileName', 'stageOrder', 'prevTask'],
#       dtype='object')

# %% [markdown]
# ## Step 2: Calculate I/O Time Breakdown
#
# Calculate the I/O time breakdown for each task in the workflow.

# %%
# Get configuration for the workflow
config = TEST_CONFIGS[WORKFLOW_NAME]
num_nodes_list = config["NUM_NODES_LIST"]

# Create task name to parallelism mapping
task_name_to_parallelism = {task: info['parallelism'] for task, info in task_order_dict.items()}

# Calculate I/O time breakdown
print("Calculating I/O time breakdown...")
io_breakdown = calculate_io_time_breakdown(wf_df, task_name_to_parallelism, num_nodes_list)

print(f"\nI/O breakdown results:")
for key, value in io_breakdown.items():
    if isinstance(value, dict):
        print(f"{key}:")
        for sub_key, sub_value in value.items():
            print(f"  {sub_key}: {sub_value:.2f} seconds")
    else:
        print(f"{key}: {value:.2f} seconds")
# Out:
# Calculating I/O time breakdown...
# Total I/O time per taskName:
#  frequency (write): 0.1182337785 (sec)
#  individuals (write): 4.4967663333333335e-05 (sec)
#  individuals_merge (write): 0.0005513027000000001 (sec)
#  mutation_overlap (write): 0.0083436507 (sec)
#  sifting (write): 0.0002396906 (sec)
#  frequency (read): 0.2121502092 (sec)
#  individuals (read): 39.60484083507334 (sec)
#  individuals_merge (read): 0.40972155000000005 (sec)
#  mutation_overlap (read): 0.0233166633 (sec)
#  sifting (read): 19.5169614252 (sec)
# Total I/O time per workflow: 59.89440407293667
#
# I/O breakdown results:
# total_io_time: 59.89 seconds
# total_write_time: 0.13 seconds
# total_read_time: 59.77 seconds
# task_io_time_adjust:
#   read: 59.77 seconds
#   write: 0.13 seconds

# %% [markdown]
# ## Step 2.1: Calculate Aggregate File Size per Node
#
# Calculate the aggregate file size per node for proper scaling.

# %%
# Calculate aggregate file size per node
print("Calculating aggregate file size per node...")
wf_df = calculate_aggregate_filesize_per_node(wf_df)

print("\nAggregate file size calculation completed.")
print(f"Updated columns: {[col for col in wf_df.columns if 'aggregateFilesizeMB' in col]}")
# Out:
# Calculating aggregate file size per node...
#
# Aggregate file size calculation completed.
# Updated columns: ['aggregateFilesizeMBtask', 'aggregateFilesizeMB']

# %%
# # Display rows with taskName include string "stage-"
# staged = insert_data_staging_rows(wf_df)
# print(staged[staged['taskName'].str.startswith('stage_')][['taskName', 'stageOrder', 'operation']])

# %% [markdown]
# ## Step 2.2: Insert data movement steps to workflow

# %%
# Step 2.2: Insert data staging (I/O) rows into the workflow DataFrame

# Set debug=True to see detailed output, or False for silent operation
wf_df = insert_data_staging_rows(wf_df, debug=False)

print("Data staging rows inserted. New DataFrame shape:", wf_df.shape)
display(wf_df.head(10))
# Out:
# Data staging rows inserted. New DataFrame shape: (6450, 19)
#   operation  randomOffset  transferSize  aggregateFilesizeMBtask  numTasks  \
# 0        cp             0        4096.0                      NaN        60
# 1        cp             0        4096.0                      NaN        60
# 2        cp             0        4096.0                      NaN        60
# 3        cp             0        4096.0                      NaN        60
# 4        cp             0        4096.0                      NaN        60
# 5        cp             0        4096.0                      NaN        60
# 6        cp             0        4096.0                      NaN        60
# 7        cp             0        4096.0                      NaN        60
# 8        cp             0        4096.0                      NaN        60
# 9        cp             0        4096.0                      NaN        60
#
#    parallelism totalTime numNodesList  numNodes  tasksPerNode trMiB  \
# 0           60             [2, 5, 10]         2            30
# 1           60             [2, 5, 10]         5            12
# 2           60             [2, 5, 10]        10             6
# 3           60             [2, 5, 10]         2            30
# 4           60             [2, 5, 10]         5            12
# 5           60             [2, 5, 10]        10             6
# 6           60             [2, 5, 10]         2            30
# 7           60             [2, 5, 10]         5            12
# 8           60             [2, 5, 10]        10             6
# 9           60             [2, 5, 10]         2            30
#
#   storageType  opCount              taskName taskPID  \
# 0  beegfs-ssd       60  stage_in-individuals
# 1  beegfs-ssd       60  stage_in-individuals
# 2  beegfs-ssd       60  stage_in-individuals
# 3  beegfs-ssd       60  stage_in-individuals
# 4  beegfs-ssd       60  stage_in-individuals
# 5  beegfs-ssd       60  stage_in-individuals
# 6  beegfs-ssd       60  stage_in-individuals
# 7  beegfs-ssd       60  stage_in-individuals
# 8  beegfs-ssd       60  stage_in-individuals
# 9  beegfs-ssd       60  stage_in-individuals
#
#                                             fileName  stageOrder prevTask  \
# 0  chr2n-2201-2401.tar.gz,ALL.chr2.250000.vcf,col...         0.5
# 1  chr2n-2201-2401.tar.gz,ALL.chr2.250000.vcf,col...         0.5
# 2  chr2n-2201-2401.tar.gz,ALL.chr2.250000.vcf,col...         0.5
# 3  chr7n-2401-2601.tar.gz,columns.txt,ALL.chr7.25...         0.5
# 4  chr7n-2401-2601.tar.gz,columns.txt,ALL.chr7.25...         0.5
# 5  chr7n-2401-2601.tar.gz,columns.txt,ALL.chr7.25...         0.5
# 6  ALL.chr8.250000.vcf,chr8n-3201-3401.tar.gz,col...         0.5
# 7  ALL.chr8.250000.vcf,chr8n-3201-3401.tar.gz,col...         0.5
# 8  ALL.chr8.250000.vcf,chr8n-3201-3401.tar.gz,col...         0.5
# 9  columns.txt,chr7n-1801-2001.tar.gz,ALL.chr7.25...         0.5
#
#    aggregateFilesizeMB
# 0         96875.299334
# 1         96875.299334
# 2         96875.299334
# 3         96873.454290
# 4         96873.454290
# 5         96873.454290
# 6         96875.235543
# 7         96875.235543
# 8         96875.235543
# 9         96874.616590

# %%
# Check for tasks being added to stage_out
for checktask in ['inference', 'aggregate']:
    new_rows = wf_df[wf_df['taskName'] == f'stage_out-{checktask}']
    if not new_rows.empty:
        print(f"\nSample of stage_out-{checktask} rows:")
        print(new_rows[['taskName', 'fileName', 'stageOrder', 'operation']].head(3))
        print(f"Total stage_out-{checktask} rows: {len(new_rows)}")
    else:
        print(f"\nNo stage_out-{checktask} tasks found in the DataFrame")
# Out:
# No stage_out-inference tasks found in the DataFrame
#
# No stage_out-aggregate tasks found in the DataFrame

# %%
# Display first few rows
print("\nFirst few rows of workflow data:")
print(wf_df.head())
print(wf_df.columns)
print(wf_df[wf_df['operation'] == 0]['taskName'].unique())
# Out:
# First few rows of workflow data:
#   operation  randomOffset  transferSize  aggregateFilesizeMBtask  numTasks  \
# 0        cp             0        4096.0                      NaN        60
# 1        cp             0        4096.0                      NaN        60
# 2        cp             0        4096.0                      NaN        60
# 3        cp             0        4096.0                      NaN        60
# 4        cp             0        4096.0                      NaN        60
#
#    parallelism totalTime numNodesList  numNodes  tasksPerNode trMiB  \
# 0           60             [2, 5, 10]         2            30
# 1           60             [2, 5, 10]         5            12
# 2           60             [2, 5, 10]        10             6
# 3           60             [2, 5, 10]         2            30
# 4           60             [2, 5, 10]         5            12
#
#   storageType  opCount              taskName taskPID  \
# 0  beegfs-ssd       60  stage_in-individuals
# 1  beegfs-ssd       60  stage_in-individuals
# 2  beegfs-ssd       60  stage_in-individuals
# 3  beegfs-ssd       60  stage_in-individuals
# 4  beegfs-ssd       60  stage_in-individuals
#
#                                             fileName  stageOrder prevTask  \
# 0  chr2n-2201-2401.tar.gz,ALL.chr2.250000.vcf,col...         0.5
# 1  chr2n-2201-2401.tar.gz,ALL.chr2.250000.vcf,col...         0.5
# 2  chr2n-2201-2401.tar.gz,ALL.chr2.250000.vcf,col...         0.5
# 3  chr7n-2401-2601.tar.gz,columns.txt,ALL.chr7.25...         0.5
# 4  chr7n-2401-2601.tar.gz,columns.txt,ALL.chr7.25...         0.5
#
#    aggregateFilesizeMB
# 0         96875.299334
# 1         96875.299334
# 2         96875.299334
# 3         96873.454290
# 4         96873.454290
# Index(['operation', 'randomOffset', 'transferSize', 'aggregateFilesizeMBtask',
#        'numTasks', 'parallelism', 'totalTime', 'numNodesList', 'numNodes',
#        'tasksPerNode', 'trMiB', 'storageType', 'opCount', 'taskName',
#        'taskPID', 'fileName', 'stageOrder', 'prevTask', 'aggregateFilesizeMB'],
#       dtype='object')
# ['individuals' 'individuals_merge' 'sifting' 'frequency'
#  'mutation_overlap']

# %% [markdown]
# ## Step 3: Load IOR Benchmark Data and Estimate Transfer Rates
#
# Load the IOR benchmark data and estimate transfer rates for different storage configurations.

# %%
# Load IOR benchmark data
print("Loading IOR benchmark data...")
if os.path.exists(IOR_DATA_PATH):
    df_ior = pd.read_csv(IOR_DATA_PATH)
    print(f"Loaded {len(df_ior)} IOR benchmark records")

    # Convert operation string to integer
    df_ior['operation'] = df_ior['operation'].map({'write': 0, 'read': 1, 'cp': 2, 'scp': 3})
    # print(df_ior.head(10))

    # Estimate transfer rates
    print("\nEstimating transfer rates...")
    cp_scp_parallelism = set(wf_df.loc[wf_df['operation'].isin(['cp', 'scp']), 'parallelism'].unique())
    ALLOWED_PARALLELISM = sorted(set(ALLOWED_PARALLELISM).union(cp_scp_parallelism))

    # Then call the function:
    wf_df = estimate_transfer_rates_for_workflow(
        wf_df, df_ior, STORAGE_LIST, ALLOWED_PARALLELISM, multi_nodes=True, debug=False
    )
    # wf_df = estimate_transfer_rates_for_workflow(wf_df, df_ior, STORAGE_LIST, ALLOWED_PARALLELISM)
    print("Transfer rate estimation completed")
    
    # Show estimated transfer rate columns
    estimated_cols = [col for col in wf_df.columns if col.startswith('estimated_trMiB_')]
    print(f"\nEstimated transfer rate columns: {len(estimated_cols)}")
    print(f"Sample columns: {estimated_cols}")
else:
    print(f"Warning: IOR data file not found at {IOR_DATA_PATH}")
    print("Skipping transfer rate estimation...")
    df_ior = pd.DataFrame()

# Save the estimated transfer rates to a new CSV file
os.makedirs("./analysis_data", exist_ok=True)
wf_df.to_csv(f"./analysis_data/{WORKFLOW_NAME}_estimated_transfer_rates.csv", index=True)
print(f"Saved estimated transfer rates to: ./analysis_data/{WORKFLOW_NAME}_estimated_transfer_rates.csv")
# Out:
# Loading IOR benchmark data...
# Loaded 21916 IOR benchmark records
#
# Estimating transfer rates...
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# Transfer rate estimation completed
#
# Estimated transfer rate columns: 66
# Sample columns: ['estimated_trMiB_beegfs-ssd_30p', 'estimated_trMiB_beegfs-ssd_12p', 'estimated_trMiB_beegfs-ssd_6p', 'estimated_trMiB_beegfs-tmpfs_30p', 'estimated_trMiB_beegfs-tmpfs_12p', 'estimated_trMiB_beegfs-tmpfs_6p', 'estimated_trMiB_ssd-ssd_30p', 'estimated_trMiB_ssd-ssd_12p', 'estimated_trMiB_ssd-ssd_6p', 'estimated_trMiB_tmpfs-tmpfs_30p', 'estimated_trMiB_tmpfs-tmpfs_12p', 'estimated_trMiB_tmpfs-tmpfs_6p', 'estimated_trMiB_localssd_150p', 'estimated_trMiB_beegfs_150p', 'estimated_trMiB_tmpfs_150p', 'estimated_trMiB_localssd_60p', 'estimated_trMiB_beegfs_60p', 'estimated_trMiB_tmpfs_60p', 'estimated_trMiB_localssd_30p', 'estimated_trMiB_beegfs_30p', 'estimated_trMiB_tmpfs_30p', 'estimated_trMiB_beegfs-ssd_5p', 'estimated_trMiB_beegfs-ssd_2p', 'estimated_trMiB_beegfs-ssd_1p', 'estimated_trMiB_beegfs-tmpfs_5p', 'estimated_trMiB_beegfs-tmpfs_2p', 'estimated_trMiB_beegfs-tmpfs_1p', 'estimated_trMiB_ssd-ssd_5p', 'estimated_trMiB_ssd-ssd_2p', 'estimated_trMiB_ssd-ssd_1p', 'estimated_trMiB_tmpfs-tmpfs_5p', 'estimated_trMiB_tmpfs-tmpfs_2p', 'estimated_trMiB_tmpfs-tmpfs_1p', 'estimated_trMiB_beegfs-ssd_20p', 'estimated_trMiB_beegfs-ssd_8p', 'estimated_trMiB_beegfs-ssd_4p', 'estimated_trMiB_beegfs-tmpfs_20p', 'estimated_trMiB_beegfs-tmpfs_8p', 'estimated_trMiB_beegfs-tmpfs_4p', 'estimated_trMiB_ssd-ssd_20p', 'estimated_trMiB_ssd-ssd_8p', 'estimated_trMiB_ssd-ssd_4p', 'estimated_trMiB_tmpfs-tmpfs_20p', 'estimated_trMiB_tmpfs-tmpfs_8p', 'estimated_trMiB_tmpfs-tmpfs_4p', 'estimated_trMiB_localssd_5p', 'estimated_trMiB_beegfs_5p', 'estimated_trMiB_tmpfs_5p', 'estimated_trMiB_localssd_2p', 'estimated_trMiB_beegfs_2p', 'estimated_trMiB_tmpfs_2p', 'estimated_trMiB_localssd_1p', 'estimated_trMiB_beegfs_1p', 'estimated_trMiB_tmpfs_1p', 'estimated_trMiB_tmpfs-beegfs_30p', 'estimated_trMiB_tmpfs-beegfs_12p', 'estimated_trMiB_tmpfs-beegfs_6p', 'estimated_trMiB_tmpfs-beegfs_10p', 'estimated_trMiB_tmpfs-beegfs_4p', 'estimated_trMiB_tmpfs-beegfs_2p', 'estimated_trMiB_ssd-beegfs_30p', 'estimated_trMiB_ssd-beegfs_12p', 'estimated_trMiB_ssd-beegfs_6p', 'estimated_trMiB_ssd-beegfs_10p', 'estimated_trMiB_ssd-beegfs_4p', 'estimated_trMiB_ssd-beegfs_2p']
# Saved estimated transfer rates to: ./analysis_data/1kg_estimated_transfer_rates.csv

# %%
# Show all rows
pd.set_option('display.max_rows', None)
# Show all columns
pd.set_option('display.max_columns', None)
# Show full width
pd.set_option('display.width', None)
# Don't truncate column content
pd.set_option('display.max_colwidth', None)

# print(wf_df.head(10))

# Check for tasks being added to stage_out
for checktask in ['inference', 'aggregate']:
    new_rows = wf_df[wf_df['taskName'] == f'stage_out-{checktask}']
    if not new_rows.empty:
        print(f"\nSample of stage_out-{checktask} rows:")
        print(new_rows.head(3))
        print(f"Total stage_out-{checktask} rows: {len(new_rows)}")
    else:
        print(f"\nNo stage_out-{checktask} tasks found in the DataFrame")
# Out:
# No stage_out-inference tasks found in the DataFrame
#
# No stage_out-aggregate tasks found in the DataFrame

# %% [markdown]
# ## Step 5: Calculate SPM Values
#
# Calculate Storage Performance Metrics (SPM) for the workflow.

# %%
# Calculate SPM values
print("Calculating SPM values...")
# Set debug=True for verbose output, debug=False for minimal output
spm_results = calculate_spm_for_workflow(wf_df, debug=False)

print(f"\nSPM calculation completed:")
print(f"- Producer-consumer pairs: {len(spm_results)}")
for pair in spm_results.keys():
    print(f"  - {pair}")
# Out:
# Calculating SPM values...
#
# SPM calculation completed:
# - Producer-consumer pairs: 15
#   - stage_in-individuals:individuals
#   - individuals:stage_out-individuals
#   - individuals:individuals_merge
#   - stage_in-individuals_merge:individuals_merge
#   - stage_in-sifting:sifting
#   - individuals_merge:stage_out-individuals_merge
#   - individuals_merge:frequency
#   - individuals_merge:mutation_overlap
#   - sifting:stage_out-sifting
#   - sifting:frequency
#   - sifting:mutation_overlap
#   - stage_in-frequency:frequency
#   - stage_in-mutation_overlap:mutation_overlap
#   - frequency:stage_out-frequency
#   - mutation_overlap:stage_out-mutation_overlap

# %%
# # printe all spm results with producer : consumer pairs

# # Print weighted SPM values for debugging
# for pair, data in spm_results.items():
#     print(f"\nProducer-Consumer Pair: {pair}")
#     print("SPM:")
#     for storage_n, spm_values in data['SPM'].items():
#         print(f"  {storage_n}: {spm_values[0:10]} ...")
#     print("estT_prod:")
#     for storage_n, estT_prod_values in data['estT_prod'].items():
#         print(f"  {storage_n}: {estT_prod_values[0:10]} ...")
#     print("estT_cons:")
#     for storage_n, estT_cons_values in data['estT_cons'].items():
#         print(f"  {storage_n}: {estT_cons_values[0:10]} ...")
#     print("dsize_prod:")
#     for storage_n, dsize_prod_values in data['dsize_prod'].items():
#         print(f"  {storage_n}: {dsize_prod_values[0:10]} ...")
#     print("dsize_cons:")
#     for storage_n, dsize_cons_values in data['dsize_cons'].items():
#         print(f"  {storage_n}: {dsize_cons_values[0:10]} ...")

# %% [markdown]
# ## Step 6: Filter Storage Options and Select Best Configuration
#
# Filter storage options and select the best storage configuration for each producer-consumer pair.

# %%
# Filter storage options
print("Filtering storage options...")
filtered_spm_results = filter_storage_options(spm_results, WORKFLOW_NAME)

# Select best storage and parallelism
print("\nSelecting best storage and parallelism...")
best_results = select_best_storage_and_parallelism(spm_results, baseline=0)

print("\nBest storage configurations:")
for pair, config in best_results.items():
    print(f"{pair}:")
    print(f"  Best storage: {config['best_storage_type']}")
    print(f"  Best parallelism: {config['best_parallelism']}")
    print(f"  Best rank: {config['best_rank']:.2f}")
# Out:
# Filtering storage options...
#
# Selecting best storage and parallelism...
# Selecting best storage configurations for 15 pairs...
# Selected best storage configurations for 15 pairs.
#
# Best storage configurations:
# stage_in-individuals:individuals:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_30_60p
#   Best rank: 541752.79
# individuals:stage_out-individuals:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_150_30p
#   Best rank: 19012.23
# individuals:individuals_merge:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_60_1p
#   Best rank: 26.50
# stage_in-individuals_merge:individuals_merge:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_30_1p
#   Best rank: 24.50
# stage_in-sifting:sifting:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_20_1p
#   Best rank: 17114.59
# individuals_merge:stage_out-individuals_merge:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_5_5p
#   Best rank: 0.05
# individuals_merge:frequency:
#   Best storage: localssd
#   Best parallelism: localssd_1_1p
#   Best rank: 51.59
# individuals_merge:mutation_overlap:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_1_1p
#   Best rank: 1.82
# sifting:stage_out-sifting:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_5_5p
#   Best rank: 0.02
# sifting:frequency:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_2_1p
#   Best rank: 81.65
# sifting:mutation_overlap:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_2_1p
#   Best rank: 2.55
# stage_in-frequency:frequency:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_30_1p
#   Best rank: 67.69
# stage_in-mutation_overlap:mutation_overlap:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_30_1p
#   Best rank: 1.52
# frequency:stage_out-frequency:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_5_5p
#   Best rank: 0.22
# mutation_overlap:stage_out-mutation_overlap:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_5_5p
#   Best rank: 0.03

# %% [markdown]
# ## Step 7: Display Top Results
#
# Display the top storage configurations based on rank values.

# %%
# Display top results
print("Displaying top results...")
display_top_sorted_averaged_rank(spm_results, top_n=20)
# Out:
# Displaying top results...
# Top 20 Averaged SPM Values Closest to Baseline = 0:
#
# Producer: stage_in-individuals, Consumer: individuals
# - Rank 1: tmpfs_30_60p with Averaged rank = 541752.7889960634
# - Rank 2: tmpfs_12_60p with Averaged rank = 541752.7889960634
# - Rank 3: tmpfs_6_60p with Averaged rank = 541752.7889960634
# - Rank 4: tmpfs_30_30p with Averaged rank = 656099.4329467526
# - Rank 5: tmpfs_12_30p with Averaged rank = 656099.4329467526
# - Rank 6: tmpfs_6_30p with Averaged rank = 656099.4329467526
# - Rank 7: tmpfs_30_150p with Averaged rank = 826115.7846037552
# - Rank 8: tmpfs_12_150p with Averaged rank = 826115.7846037552
# - Rank 9: tmpfs_6_150p with Averaged rank = 826115.7846037552
#
# Producer: individuals, Consumer: stage_out-individuals
# - Rank 1: beegfs-tmpfs_150_12p with Averaged rank = 15870.89332779289
# - Rank 2: beegfs-tmpfs_60_12p with Averaged rank = 15870.89332779289
# - Rank 3: beegfs-tmpfs_30_12p with Averaged rank = 15870.89332779289
# - Rank 4: beegfs-tmpfs_150_6p with Averaged rank = 17098.85443905679
# - Rank 5: beegfs-tmpfs_60_6p with Averaged rank = 17098.85443905679
# - Rank 6: beegfs-tmpfs_30_6p with Averaged rank = 17098.85443905679
# - Rank 7: beegfs-ssd_150_30p with Averaged rank = 19012.226067467996
# - Rank 8: beegfs-ssd_60_30p with Averaged rank = 19012.226067467996
# - Rank 9: beegfs-ssd_30_30p with Averaged rank = 19012.226067467996
# - Rank 10: beegfs-ssd_150_6p with Averaged rank = 20420.579301592625
# - Rank 11: beegfs-ssd_60_6p with Averaged rank = 20420.579301592625
# - Rank 12: beegfs-ssd_30_6p with Averaged rank = 20420.579301592625
# - Rank 13: beegfs-ssd_150_12p with Averaged rank = 21459.329607702846
# - Rank 14: beegfs-ssd_60_12p with Averaged rank = 21459.329607702846
# - Rank 15: beegfs-ssd_30_12p with Averaged rank = 21459.329607702846
# - Rank 16: beegfs-tmpfs_150_30p with Averaged rank = 44972.02903104664
# - Rank 17: beegfs-tmpfs_60_30p with Averaged rank = 44972.02903104664
# - Rank 18: beegfs-tmpfs_30_30p with Averaged rank = 44972.02903104664
# - Rank 19: tmpfs-tmpfs_150_6p with Averaged rank = 50312.784889782866
# - Rank 20: tmpfs-tmpfs_60_6p with Averaged rank = 50312.784889782866
#
# Producer: individuals, Consumer: individuals_merge
# - Rank 1: tmpfs_60_1p with Averaged rank = 26.50348777832273
# - Rank 2: tmpfs_30_1p with Averaged rank = 27.971157806990412
# - Rank 3: tmpfs_60_2p with Averaged rank = 28.230953711779456
# - Rank 4: tmpfs_60_5p with Averaged rank = 29.534936377149656
# - Rank 5: tmpfs_30_2p with Averaged rank = 29.69862374044714
# - Rank 6: tmpfs_150_1p with Averaged rank = 29.891782801730663
# - Rank 7: tmpfs_30_5p with Averaged rank = 31.00260640581734
# - Rank 8: tmpfs_150_2p with Averaged rank = 31.61924873518739
# - Rank 9: tmpfs_150_5p with Averaged rank = 32.92323140055759
# - Rank 10: beegfs_30_1p with Averaged rank = 107.2072317424045
# - Rank 11: beegfs_60_1p with Averaged rank = 112.41657941737347
# - Rank 12: beegfs_30_2p with Averaged rank = 150.13588846442755
# - Rank 13: beegfs_60_2p with Averaged rank = 155.34523613939652
# - Rank 14: beegfs_30_5p with Averaged rank = 168.01127454771535
# - Rank 15: beegfs_60_5p with Averaged rank = 173.2206222226843
# - Rank 16: localssd_30_1p with Averaged rank = 242.75136481757727
# - Rank 17: localssd_30_2p with Averaged rank = 252.6472386907182
# - Rank 18: localssd_30_5p with Averaged rank = 257.4849649572449
# - Rank 19: beegfs_150_1p with Averaged rank = 284.4919062138683
# - Rank 20: beegfs_150_2p with Averaged rank = 327.4205629358913
#
# Producer: stage_in-individuals_merge, Consumer: individuals_merge
# - Rank 1: tmpfs_30_1p with Averaged rank = 24.497258340195405
# - Rank 2: tmpfs_12_1p with Averaged rank = 24.497258340195405
# - Rank 3: tmpfs_6_1p with Averaged rank = 24.497258340195405
# - Rank 4: tmpfs_5_1p with Averaged rank = 24.497258340195405
# - Rank 5: tmpfs_2_1p with Averaged rank = 24.497258340195405
# - Rank 6: tmpfs_1_1p with Averaged rank = 24.497258340195405
# - Rank 7: tmpfs_30_2p with Averaged rank = 26.233933977903305
# - Rank 8: tmpfs_12_2p with Averaged rank = 26.233933977903305
# - Rank 9: tmpfs_6_2p with Averaged rank = 26.233933977903305
# - Rank 10: tmpfs_5_2p with Averaged rank = 26.233933977903305
# - Rank 11: tmpfs_2_2p with Averaged rank = 26.233933977903305
# - Rank 12: tmpfs_1_2p with Averaged rank = 26.233933977903305
# - Rank 13: tmpfs_30_5p with Averaged rank = 27.546984797426557
# - Rank 14: tmpfs_12_5p with Averaged rank = 27.546984797426557
# - Rank 15: tmpfs_6_5p with Averaged rank = 27.546984797426557
# - Rank 16: tmpfs_5_5p with Averaged rank = 27.546984797426557
# - Rank 17: tmpfs_2_5p with Averaged rank = 27.546984797426557
# - Rank 18: tmpfs_1_5p with Averaged rank = 27.546984797426557
#
# Producer: stage_in-sifting, Consumer: sifting
# - Rank 1: tmpfs_20_1p with Averaged rank = 17114.586037630743
# - Rank 2: tmpfs_8_1p with Averaged rank = 17114.586037630743
# - Rank 3: tmpfs_4_1p with Averaged rank = 17114.586037630743
# - Rank 4: tmpfs_20_2p with Averaged rank = 18218.19216015272
# - Rank 5: tmpfs_8_2p with Averaged rank = 18218.19216015272
# - Rank 6: tmpfs_4_2p with Averaged rank = 18218.19216015272
# - Rank 7: tmpfs_20_5p with Averaged rank = 20676.183045895858
# - Rank 8: tmpfs_8_5p with Averaged rank = 20676.183045895858
# - Rank 9: tmpfs_4_5p with Averaged rank = 20676.183045895858
#
# Producer: individuals_merge, Consumer: stage_out-individuals_merge
# - Rank 1: beegfs-ssd_5_5p with Averaged rank = 0.05197163080576004
# - Rank 2: beegfs-ssd_2_5p with Averaged rank = 0.05197163080576004
# - Rank 3: beegfs-ssd_1_5p with Averaged rank = 0.05197163080576004
# - Rank 4: beegfs-ssd_5_2p with Averaged rank = 0.05361221125880895
# - Rank 5: beegfs-ssd_2_2p with Averaged rank = 0.05361221125880895
# - Rank 6: beegfs-ssd_1_2p with Averaged rank = 0.05361221125880895
# - Rank 7: beegfs-tmpfs_5_2p with Averaged rank = 0.05583884731944918
# - Rank 8: beegfs-tmpfs_2_2p with Averaged rank = 0.05583884731944918
# - Rank 9: beegfs-tmpfs_1_2p with Averaged rank = 0.05583884731944918
# - Rank 10: beegfs-tmpfs_5_1p with Averaged rank = 0.06320277238367408
# - Rank 11: beegfs-tmpfs_2_1p with Averaged rank = 0.06320277238367408
# - Rank 12: beegfs-tmpfs_1_1p with Averaged rank = 0.06320277238367408
# - Rank 13: beegfs-ssd_5_1p with Averaged rank = 0.06458147897991655
# - Rank 14: beegfs-ssd_2_1p with Averaged rank = 0.06458147897991655
# - Rank 15: beegfs-ssd_1_1p with Averaged rank = 0.06458147897991655
# - Rank 16: beegfs-tmpfs_5_5p with Averaged rank = 0.6248491864683522
# - Rank 17: beegfs-tmpfs_2_5p with Averaged rank = 0.6248491864683522
# - Rank 18: beegfs-tmpfs_1_5p with Averaged rank = 0.6248491864683522
# - Rank 19: beegfs-ssd_5_30p with Averaged rank = 1.6441450468965448
# - Rank 20: beegfs-ssd_2_30p with Averaged rank = 1.6441450468965448
#
# Producer: individuals_merge, Consumer: frequency
# - Rank 1: localssd_1_1p with Averaged rank = 51.58513719013285
# - Rank 2: localssd_2_1p with Averaged rank = 51.648520855974965
# - Rank 3: localssd_5_1p with Averaged rank = 51.9428932403497
# - Rank 4: tmpfs_1_1p with Averaged rank = 80.92592396998334
# - Rank 5: tmpfs_2_1p with Averaged rank = 80.92648154829224
# - Rank 6: tmpfs_5_1p with Averaged rank = 80.93318214263194
# - Rank 7: localssd_1_2p with Averaged rank = 84.05523968858587
# - Rank 8: localssd_2_2p with Averaged rank = 84.11862335442798
# - Rank 9: localssd_5_2p with Averaged rank = 84.4129957388027
# - Rank 10: tmpfs_1_2p with Averaged rank = 84.72460615508885
# - Rank 11: tmpfs_2_2p with Averaged rank = 84.72516373339775
# - Rank 12: tmpfs_5_2p with Averaged rank = 84.73186432773744
# - Rank 13: tmpfs_1_5p with Averaged rank = 86.96296421849918
# - Rank 14: tmpfs_2_5p with Averaged rank = 86.96352179680808
# - Rank 15: tmpfs_5_5p with Averaged rank = 86.97022239114777
# - Rank 16: localssd_1_5p with Averaged rank = 96.0977399982417
# - Rank 17: localssd_2_5p with Averaged rank = 96.16112366408382
# - Rank 18: localssd_5_5p with Averaged rank = 96.45549604845854
# - Rank 19: beegfs_1_1p with Averaged rank = 192.03868368168378
# - Rank 20: beegfs_2_1p with Averaged rank = 192.07516922671346
#
# Producer: individuals_merge, Consumer: mutation_overlap
# - Rank 1: localssd_1_1p with Averaged rank = 1.3795120762102293
# - Rank 2: localssd_2_1p with Averaged rank = 1.4428957420523432
# - Rank 3: localssd_5_1p with Averaged rank = 1.7372681264270773
# - Rank 4: tmpfs_1_1p with Averaged rank = 1.8223426015690742
# - Rank 5: tmpfs_2_1p with Averaged rank = 1.8229001798779751
# - Rank 6: tmpfs_5_1p with Averaged rank = 1.8296007742176694
# - Rank 7: tmpfs_1_2p with Averaged rank = 2.042893517294399
# - Rank 8: tmpfs_2_2p with Averaged rank = 2.0434510956033
# - Rank 9: tmpfs_5_2p with Averaged rank = 2.0501516899429943
# - Rank 10: localssd_1_2p with Averaged rank = 2.1202951686429508
# - Rank 11: localssd_2_2p with Averaged rank = 2.1836788344850646
# - Rank 12: tmpfs_1_5p with Averaged rank = 2.245678893385688
# - Rank 13: tmpfs_2_5p with Averaged rank = 2.246236471694589
# - Rank 14: tmpfs_5_5p with Averaged rank = 2.252937066034283
# - Rank 15: localssd_5_2p with Averaged rank = 2.4780512188597985
# - Rank 16: localssd_1_5p with Averaged rank = 2.5544925389833133
# - Rank 17: localssd_2_5p with Averaged rank = 2.617876204825427
# - Rank 18: localssd_5_5p with Averaged rank = 2.912248589200161
# - Rank 19: beegfs_1_1p with Averaged rank = 6.138317308966809
# - Rank 20: beegfs_2_1p with Averaged rank = 6.17480285399649
#
# Producer: sifting, Consumer: stage_out-sifting
# - Rank 1: beegfs-ssd_5_5p with Averaged rank = 0.021151050896167114
# - Rank 2: beegfs-ssd_2_5p with Averaged rank = 0.021151050896167114
# - Rank 3: beegfs-ssd_1_5p with Averaged rank = 0.021151050896167114
# - Rank 4: beegfs-ssd_5_2p with Averaged rank = 0.02181862680063159
# - Rank 5: beegfs-ssd_2_2p with Averaged rank = 0.02181862680063159
# - Rank 6: beegfs-ssd_1_2p with Averaged rank = 0.02181862680063159
# - Rank 7: beegfs-tmpfs_5_2p with Averaged rank = 0.02272178295313235
# - Rank 8: beegfs-tmpfs_2_2p with Averaged rank = 0.02272178295313235
# - Rank 9: beegfs-tmpfs_1_2p with Averaged rank = 0.02272178295313235
# - Rank 10: beegfs-tmpfs_5_1p with Averaged rank = 0.02572162215741825
# - Rank 11: beegfs-tmpfs_2_1p with Averaged rank = 0.02572162215741825
# - Rank 12: beegfs-tmpfs_1_1p with Averaged rank = 0.02572162215741825
# - Rank 13: beegfs-ssd_5_1p with Averaged rank = 0.026284365345847722
# - Rank 14: beegfs-ssd_2_1p with Averaged rank = 0.026284365345847722
# - Rank 15: beegfs-ssd_1_1p with Averaged rank = 0.026284365345847722
# - Rank 16: beegfs-tmpfs_5_5p with Averaged rank = 0.25417266052033705
# - Rank 17: beegfs-tmpfs_2_5p with Averaged rank = 0.25417266052033705
# - Rank 18: beegfs-tmpfs_1_5p with Averaged rank = 0.25417266052033705
# - Rank 19: tmpfs-tmpfs_5_1p with Averaged rank = 0.7143466934303088
# - Rank 20: tmpfs-tmpfs_2_1p with Averaged rank = 0.7143466934303088
#
# Producer: sifting, Consumer: frequency
# - Rank 1: localssd_1_1p with Averaged rank = 56.17640006524784
# - Rank 2: localssd_2_1p with Averaged rank = 59.38795448304114
# - Rank 3: localssd_5_1p with Averaged rank = 74.94673643990414
# - Rank 4: tmpfs_2_1p with Averaged rank = 81.65147909892875
# - Rank 5: tmpfs_1_1p with Averaged rank = 81.67613293125149
# - Rank 6: tmpfs_5_1p with Averaged rank = 81.76261435868152
# - Rank 7: tmpfs_2_2p with Averaged rank = 85.45016128403428
# - Rank 8: tmpfs_1_2p with Averaged rank = 85.47481511635702
# - Rank 9: tmpfs_5_2p with Averaged rank = 85.56129654378705
# - Rank 10: tmpfs_2_5p with Averaged rank = 87.68851934744457
# - Rank 11: tmpfs_1_5p with Averaged rank = 87.71317317976731
# - Rank 12: tmpfs_5_5p with Averaged rank = 87.79965460719734
# - Rank 13: localssd_1_2p with Averaged rank = 88.64650256370082
# - Rank 14: localssd_2_2p with Averaged rank = 91.85805698149412
# - Rank 15: localssd_1_5p with Averaged rank = 100.68900287335667
# - Rank 16: localssd_2_5p with Averaged rank = 103.90055729114997
# - Rank 17: localssd_5_2p with Averaged rank = 107.41683893835713
# - Rank 18: localssd_5_5p with Averaged rank = 119.45933924801298
# - Rank 19: beegfs_1_1p with Averaged rank = 193.5742687557017
# - Rank 20: beegfs_2_1p with Averaged rank = 194.5908170058908
#
# Producer: sifting, Consumer: mutation_overlap
# - Rank 1: tmpfs_2_1p with Averaged rank = 2.5478977305144688
# - Rank 2: tmpfs_1_1p with Averaged rank = 2.5725515628372158
# - Rank 3: tmpfs_5_1p with Averaged rank = 2.659032990267245
# - Rank 4: tmpfs_2_2p with Averaged rank = 2.7684486462397935
# - Rank 5: tmpfs_1_2p with Averaged rank = 2.7931024785625405
# - Rank 6: tmpfs_5_2p with Averaged rank = 2.87958390599257
# - Rank 7: tmpfs_2_5p with Averaged rank = 2.9712340223310827
# - Rank 8: tmpfs_1_5p with Averaged rank = 2.9958878546538297
# - Rank 9: tmpfs_5_5p with Averaged rank = 3.0823692820838593
# - Rank 10: localssd_1_1p with Averaged rank = 5.970774951325231
# - Rank 11: localssd_1_2p with Averaged rank = 6.711558043757952
# - Rank 12: localssd_1_5p with Averaged rank = 7.145755414098314
# - Rank 13: beegfs_1_1p with Averaged rank = 7.673902382984736
# - Rank 14: beegfs_2_1p with Averaged rank = 8.690450633173855
# - Rank 15: beegfs_5_1p with Averaged rank = 8.930416174981344
# - Rank 16: localssd_2_1p with Averaged rank = 9.182329369118527
# - Rank 17: localssd_2_2p with Averaged rank = 9.92311246155125
# - Rank 18: localssd_2_5p with Averaged rank = 10.35730983189161
# - Rank 19: beegfs_1_2p with Averaged rank = 10.83144600377528
# - Rank 20: beegfs_2_2p with Averaged rank = 11.847994253964398
#
# Producer: stage_in-frequency, Consumer: frequency
# - Rank 1: tmpfs_30_1p with Averaged rank = 67.68976377854655
# - Rank 2: tmpfs_12_1p with Averaged rank = 67.68976377854655
# - Rank 3: tmpfs_6_1p with Averaged rank = 67.68976377854655
# - Rank 4: tmpfs_20_1p with Averaged rank = 67.68976377854655
# - Rank 5: tmpfs_8_1p with Averaged rank = 67.68976377854655
# - Rank 6: tmpfs_4_1p with Averaged rank = 67.68976377854655
# - Rank 7: tmpfs_30_2p with Averaged rank = 72.02090984975557
# - Rank 8: tmpfs_12_2p with Averaged rank = 72.02090984975557
# - Rank 9: tmpfs_6_2p with Averaged rank = 72.02090984975557
# - Rank 10: tmpfs_20_2p with Averaged rank = 72.02090984975557
# - Rank 11: tmpfs_8_2p with Averaged rank = 72.02090984975557
# - Rank 12: tmpfs_4_2p with Averaged rank = 72.02090984975557
# - Rank 13: tmpfs_30_5p with Averaged rank = 76.0355121577176
# - Rank 14: tmpfs_12_5p with Averaged rank = 76.0355121577176
# - Rank 15: tmpfs_6_5p with Averaged rank = 76.0355121577176
# - Rank 16: tmpfs_20_5p with Averaged rank = 76.0355121577176
# - Rank 17: tmpfs_8_5p with Averaged rank = 76.0355121577176
# - Rank 18: tmpfs_4_5p with Averaged rank = 76.0355121577176
#
# Producer: stage_in-mutation_overlap, Consumer: mutation_overlap
# - Rank 1: tmpfs_30_1p with Averaged rank = 1.520983391277426
# - Rank 2: tmpfs_12_1p with Averaged rank = 1.520983391277426
# - Rank 3: tmpfs_6_1p with Averaged rank = 1.520983391277426
# - Rank 4: tmpfs_20_1p with Averaged rank = 1.520983391277426
# - Rank 5: tmpfs_8_1p with Averaged rank = 1.520983391277426
# - Rank 6: tmpfs_4_1p with Averaged rank = 1.520983391277426
# - Rank 7: tmpfs_30_2p with Averaged rank = 1.7081969278157232
# - Rank 8: tmpfs_12_2p with Averaged rank = 1.7081969278157232
# - Rank 9: tmpfs_6_2p with Averaged rank = 1.7081969278157232
# - Rank 10: tmpfs_20_2p with Averaged rank = 1.7081969278157232
# - Rank 11: tmpfs_8_2p with Averaged rank = 1.7081969278157232
# - Rank 12: tmpfs_4_2p with Averaged rank = 1.7081969278157232
# - Rank 13: tmpfs_30_5p with Averaged rank = 1.8802118177696752
# - Rank 14: tmpfs_12_5p with Averaged rank = 1.8802118177696752
# - Rank 15: tmpfs_6_5p with Averaged rank = 1.8802118177696752
# - Rank 16: tmpfs_20_5p with Averaged rank = 1.8802118177696752
# - Rank 17: tmpfs_8_5p with Averaged rank = 1.8802118177696752
# - Rank 18: tmpfs_4_5p with Averaged rank = 1.8802118177696752
#
# Producer: frequency, Consumer: stage_out-frequency
# - Rank 1: beegfs-ssd_5_5p with Averaged rank = 0.21664913892063487
# - Rank 2: beegfs-ssd_2_5p with Averaged rank = 0.21664913892063487
# - Rank 3: beegfs-ssd_1_5p with Averaged rank = 0.21664913892063487
# - Rank 4: beegfs-ssd_5_2p with Averaged rank = 0.22349307491189935
# - Rank 5: beegfs-ssd_2_2p with Averaged rank = 0.22349307491189935
# - Rank 6: beegfs-ssd_1_2p with Averaged rank = 0.22349307491189935
# - Rank 7: beegfs-tmpfs_5_2p with Averaged rank = 0.23293279829870422
# - Rank 8: beegfs-tmpfs_2_2p with Averaged rank = 0.23293279829870422
# - Rank 9: beegfs-tmpfs_1_2p with Averaged rank = 0.23293279829870422
# - Rank 10: beegfs-tmpfs_5_1p with Averaged rank = 0.2634777526446701
# - Rank 11: beegfs-tmpfs_2_1p with Averaged rank = 0.2634777526446701
# - Rank 12: beegfs-tmpfs_1_1p with Averaged rank = 0.2634777526446701
# - Rank 13: beegfs-ssd_5_1p with Averaged rank = 0.26913923616571367
# - Rank 14: beegfs-ssd_2_1p with Averaged rank = 0.26913923616571367
# - Rank 15: beegfs-ssd_1_1p with Averaged rank = 0.26913923616571367
# - Rank 16: tmpfs-beegfs_5_4p with Averaged rank = 0.3053735449863574
# - Rank 17: tmpfs-beegfs_2_4p with Averaged rank = 0.3053735449863574
# - Rank 18: tmpfs-beegfs_1_4p with Averaged rank = 0.3053735449863574
# - Rank 19: tmpfs-beegfs_5_2p with Averaged rank = 0.3135017179755764
# - Rank 20: tmpfs-beegfs_2_2p with Averaged rank = 0.3135017179755764
#
# Producer: mutation_overlap, Consumer: stage_out-mutation_overlap
# - Rank 1: beegfs-ssd_5_5p with Averaged rank = 0.029967072486020617
# - Rank 2: beegfs-ssd_2_5p with Averaged rank = 0.029967072486020617
# - Rank 3: beegfs-ssd_1_5p with Averaged rank = 0.029967072486020617
# - Rank 4: beegfs-ssd_5_2p with Averaged rank = 0.030912939708458674
# - Rank 5: beegfs-ssd_2_2p with Averaged rank = 0.030912939708458674
# - Rank 6: beegfs-ssd_1_2p with Averaged rank = 0.030912939708458674
# - Rank 7: beegfs-tmpfs_5_2p with Averaged rank = 0.03219371892111465
# - Rank 8: beegfs-tmpfs_2_2p with Averaged rank = 0.03219371892111465
# - Rank 9: beegfs-tmpfs_1_2p with Averaged rank = 0.03219371892111465
# - Rank 10: beegfs-tmpfs_5_1p with Averaged rank = 0.03644279267660045
# - Rank 11: beegfs-tmpfs_2_1p with Averaged rank = 0.03644279267660045
# - Rank 12: beegfs-tmpfs_1_1p with Averaged rank = 0.03644279267660045
# - Rank 13: beegfs-ssd_5_1p with Averaged rank = 0.037239453670658944
# - Rank 14: beegfs-ssd_2_1p with Averaged rank = 0.037239453670658944
# - Rank 15: beegfs-ssd_1_1p with Averaged rank = 0.037239453670658944
# - Rank 16: tmpfs-beegfs_5_4p with Averaged rank = 0.3053735449863574
# - Rank 17: tmpfs-beegfs_2_4p with Averaged rank = 0.3053735449863574
# - Rank 18: tmpfs-beegfs_1_4p with Averaged rank = 0.3053735449863574
# - Rank 19: tmpfs-beegfs_5_2p with Averaged rank = 0.3135017179755764
# - Rank 20: tmpfs-beegfs_2_2p with Averaged rank = 0.3135017179755764

# %% [markdown]
# ## Step 8: Generate Visualizations
#
# Generate comprehensive visualizations of the analysis results.

# %%
# # Generate visualizations
# print("Generating visualizations...")
# plot_all_visualizations(wf_df, best_results, io_breakdown['task_io_time_adjust'])
# print("Visualizations completed!")

# %% [markdown]
# ## Step 9: Save Results
#
# Save the analysis results to files for future reference.

# %%
#FIXME Step 9: Debug and save filtered SPM results
import os
import pandas as pd
import numpy as np
from modules.workflow_results_exporter import extract_producer_consumer_results, print_storage_analysis

# Debug: Check what's in filtered_spm_results
print("=== Debugging filtered_spm_results ===")
print(f"Type: {type(filtered_spm_results)}")
print(f"Length: {len(filtered_spm_results) if filtered_spm_results else 'None/Empty'}")

if filtered_spm_results:
    print(f"Keys: {list(filtered_spm_results.keys())[:5]}...")  # First 5 keys
    
    # Examine first item structure
    first_key = list(filtered_spm_results.keys())[0]
    first_value = filtered_spm_results[first_key]
    print(f"\nFirst item - Key: '{first_key}'")
    print(f"  Type: {type(first_value)}")
    if isinstance(first_value, dict):
        print(f"  Keys: {list(first_value.keys())}")
        for k, v in first_value.items():
            print(f"    {k}: {type(v)} = {v}")

# Try to extract results
print("\n=== Attempting to Extract Results ===")
try:
    results_df = extract_producer_consumer_results(filtered_spm_results, wf_df)
    print(f"Extracted {len(results_df)} rows")
    
    if not results_df.empty:
        print("Sample data:")
        print(results_df.head())
        
        # Save to CSV
        output_dir = "workflow_spm_results"
        os.makedirs(output_dir, exist_ok=True)
        workflow_name = "ddmd_4n_l"  # or your workflow name
        csv_filename = f"{workflow_name}_filtered_spm_results.csv"
        csv_path = os.path.join(output_dir, csv_filename)
        
        results_df.to_csv(csv_path, index=False)
        print(f"✓ Saved to: {csv_path}")
        
        # Print storage analysis
        print_storage_analysis(results_df)
        
    else:
        print("Error: Extracted DataFrame is empty - trying alternative method...")
        
        # Alternative extraction method
        results_data = []
        for pair, data in filtered_spm_results.items():
            if isinstance(data, dict):
                # Try to find storage and SPM information
                storage_info = None
                spm_value = None
                
                # Look for storage-related keys
                for key in data.keys():
                    if 'storage' in key.lower() or 'type' in key.lower():
                        storage_info = data[key]
                    if 'spm' in key.lower() or 'rank' in key.lower():
                        spm_value = data[key]
                
                if storage_info:
                    producer, consumer = pair.split(':') if ':' in pair else ('unknown', 'unknown')
                    results_data.append({
                        'producer': producer,
                        'producerStage': -1,
                        'consumer': consumer,
                        'consumerStage': -1,
                        'prodParallelism': np.nan,
                        'consParallelism': np.nan,
                        'p-c-Storage': storage_info,
                        'p-c-SPM': spm_value if spm_value else np.nan
                    })
        
        if results_data:
            alt_df = pd.DataFrame(results_data)
            
            # Fill stage information
            task_stage_mapping = {}
            for _, row in wf_df.iterrows():
                task_name = row['taskName']
                stage_order = row['stageOrder']
                if task_name not in task_stage_mapping:
                    task_stage_mapping[task_name] = stage_order
            
            for i, row in alt_df.iterrows():
                if row['producer'] in task_stage_mapping:
                    alt_df.at[i, 'producerStage'] = task_stage_mapping[row['producer']]
                if row['consumer'] in task_stage_mapping:
                    alt_df.at[i, 'consumerStage'] = task_stage_mapping[row['consumer']]
            
            # Save alternative results
            output_dir = "workflow_spm_results"
            os.makedirs(output_dir, exist_ok=True)
            workflow_name = "ddmd_4n_l"
            csv_filename = f"{workflow_name}_filtered_spm_results_alt.csv"
            csv_path = os.path.join(output_dir, csv_filename)
            
            alt_df.to_csv(csv_path, index=False)
            print(f"✓ Saved alternative results to: {csv_path}")
            print(f"Alternative DataFrame shape: {alt_df.shape}")
            print(alt_df.head())
        else:
            print("Error: No data could be extracted with alternative method")
            
except Exception as e:
    print(f"Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# === Debugging filtered_spm_results ===
# Type: <class 'dict'>
# Length: 15
# Keys: ['stage_in-individuals:individuals', 'individuals:stage_out-individuals', 'individuals:individuals_merge', 'stage_in-individuals_merge:individuals_merge', 'stage_in-sifting:sifting']...
#
# First item - Key: 'stage_in-individuals:individuals'
#   Type: <class 'dict'>
#   Keys: ['SPM', 'estT_prod', 'estT_cons', 'rank', 'par_prod', 'par_cons', 'dsize_prod', 'dsize_cons']
#     SPM: <class 'dict'> = {'tmpfs_30_150p': [633.0774095084666], 'tmpfs_30_60p': [1581.2511084869695], 'tmpfs_30_30p': [958.850520396719], 'tmpfs_12_150p': [614.7773446933302], 'tmpfs_12_60p': [1535.5426416549562], 'tmpfs_12_30p': [931.1334886280622], 'tmpfs_6_150p': [613.8894221402886], 'tmpfs_6_60p': [1533.3248583314153], 'tmpfs_6_30p': [929.7886530845929]}
#     estT_prod: <class 'dict'> = {'beegfs-tmpfs_30p': [46512.55708453747, 46511.60313628819, 46512.52410278834, 46512.20408349901, 46511.84024443488, 46511.76013065692, 46512.34915347363, 46512.09748722872, 46512.06863360101, 46512.568419502866, 46511.66410864266, 46512.93756050911, 46511.8082646983, 46512.02310249589, 46512.128815140364], 'beegfs-tmpfs_12p': [16414.847958090853, 16413.86085536962, 16414.813828755356, 16414.482679382734, 16414.1061969043, 16414.02330069981, 16414.63279371507, 16414.372377711396, 16414.342521268536, 16414.859687473294, 16413.923944478018, 16415.24167932934, 16414.073106415355, 16414.29540786388, 16414.404794513597], 'beegfs-tmpfs_6p': [17684.948111180427, 17683.765492749008, 17684.90722157202, 17684.5104797598, 17684.05942766152, 17683.96011257546, 17684.69032777881, 17684.37833047388, 17684.3425603556, 17684.96216390071, 17683.841077457946, 17685.41982133955, 17684.01978307351, 17684.286115213108, 17684.417168099215], 'tmpfs-tmpfs_30p': [53662.60923210515, 53661.63067332678, 53662.57539954735, 53662.24712465294, 53661.87389894729, 53661.79171823635, 53662.39593709034, 53662.13777838497, 53662.10818037448, 53662.62085947002, 53661.69321881576, 53662.999522582526, 53661.84109413826, 53662.061474622984, 53662.1699145078], 'tmpfs-tmpfs_12p': [52111.423504859624, 52110.443026336616, 52111.38960590987, 52111.060686889556, 52110.68672901301, 52110.60438710728, 52111.20979130403, 52110.95112609578, 52110.921470019566, 52111.435155042, 52110.50569449385, 52111.81456132916, 52110.653859857455, 52110.87467264229, 52110.98332526482], 'tmpfs-tmpfs_6p': [52036.16226416265, 52035.175946420175, 52036.12816332381, 52035.79728540565, 52035.421100437095, 52035.33826815264, 52035.947277816966, 52035.68707212256, 52035.65723943018, 52036.173983729095, 52035.238987788085, 52036.55564963759, 52035.38803553244, 52035.61016335256, 52035.719463053385], 'tmpfs_30p': [0.0], 'tmpfs_12p': [0.0], 'tmpfs_6p': [0.0]}
#     estT_cons: <class 'dict'> = {'tmpfs_150p': [826115.7846037552], 'tmpfs_60p': [541752.7889960634], 'tmpfs_30p': [656099.4329467526]}
#     rank: <class 'dict'> = {'tmpfs_30_150p': [826115.7846037552], 'tmpfs_30_60p': [541752.7889960634], 'tmpfs_30_30p': [656099.4329467526], 'tmpfs_12_150p': [826115.7846037552], 'tmpfs_12_60p': [541752.7889960634], 'tmpfs_12_30p': [656099.4329467526], 'tmpfs_6_150p': [826115.7846037552], 'tmpfs_6_60p': [541752.7889960634], 'tmpfs_6_30p': [656099.4329467526]}
#     par_prod: <class 'dict'> = {'prod_max_parallelism': [60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60]}
#     par_cons: <class 'dict'> = {'cons_max_parallelism': [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]}
#     dsize_prod: <class 'dict'> = {'prod_aggregateFilesizeMB': [96875.29933357239, 96873.45429039001, 96875.23554325104, 96874.61659049988, 96873.91288471222, 96873.75793552399, 96874.89717197418, 96874.41042137146, 96874.35461521149, 96875.32125663757, 96873.57221794128, 96876.03521537781, 96873.85103225708, 96874.26655292511, 96874.47101306915], 'tmpfs_30_150p': [0], 'tmpfs_30_60p': [0], 'tmpfs_30_30p': [0], 'tmpfs_12_150p': [0], 'tmpfs_12_60p': [0], 'tmpfs_12_30p': [0], 'tmpfs_6_150p': [0], 'tmpfs_6_60p': [0], 'tmpfs_6_30p': [0]}
#     dsize_cons: <class 'dict'> = {'cons_aggregateFilesizeMB': [726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573, 726558.7280373573], 'tmpfs_30_150p': [0], 'tmpfs_30_60p': [0], 'tmpfs_30_30p': [0], 'tmpfs_12_150p': [0], 'tmpfs_12_60p': [0], 'tmpfs_12_30p': [0], 'tmpfs_6_150p': [0], 'tmpfs_6_60p': [0], 'tmpfs_6_30p': [0]}
#
# === Attempting to Extract Results ===
# Extracted 15 rows
# Sample data:
#                      producer  producerStage               consumer  \
# 0        stage_in-individuals            0.5            individuals
# 1                 individuals            1.0  stage_out-individuals
# 2                 individuals            1.0      individuals_merge
# 3  stage_in-individuals_merge            1.5      individuals_merge
# 4            stage_in-sifting            1.5                sifting
#
#    consumerStage prodParallelism consParallelism   p-c-Storage        p-c-SPM
# 0            1.0              30             60p         tmpfs  541752.788996
# 1            1.5             150             12p  beegfs-tmpfs   15870.893328
# 2            2.0             150              1p      localssd    -427.916289
# 3            2.0              30              1p         tmpfs      24.497258
# 4            2.0              20              1p         tmpfs   17114.586038
# ✓ Saved to: workflow_spm_results/ddmd_4n_l_filtered_spm_results.csv
#
# === Storage Distribution Analysis ===
#
# Storage Type Usage:
#   tmpfs: 6 pairs (40.0%)
#   localssd: 4 pairs (26.7%)
#   beegfs-ssd: 4 pairs (26.7%)
#   beegfs-tmpfs: 1 pairs (6.7%)
#
# SPM Performance by Storage Type:
#   beegfs-ssd:
#     Mean SPM: 0.0799
#     Min SPM: 0.0212
#     Max SPM: 0.2166
#     Std Dev: 0.0921
#   beegfs-tmpfs:
#     Mean SPM: 15870.8933
#     Min SPM: 15870.8933
#     Max SPM: 15870.8933
#     Std Dev: nan
#   localssd:
#     Mean SPM: -79.6938
#     Min SPM: -427.9163
#     Max SPM: 56.1764
#     Std Dev: 233.4714
#   tmpfs:
#     Mean SPM: 93160.6052
#     Min SPM: 1.5210
#     Max SPM: 541752.7890
#     Std Dev: 219870.6931
#
# Stage-wise Analysis:
#   Stage 0.5:
#     Pairs: 1
#     Avg SPM: 541752.7890
#     Storage types: tmpfs
#   Stage 1.0:
#     Pairs: 2
#     Avg SPM: 7721.4885
#     Storage types: beegfs-tmpfs, localssd
#   Stage 1.5:
#     Pairs: 2
#     Avg SPM: 8569.5416
#     Storage types: tmpfs
#   Stage 2.0:
#     Pairs: 6
#     Avg SPM: 18.6270
#     Storage types: beegfs-ssd, localssd, tmpfs
#   Stage 2.5:
#     Pairs: 2
#     Avg SPM: 34.6054
#     Storage types: tmpfs
#   Stage 3.0:
#     Pairs: 2
#     Avg SPM: 0.1233
#     Storage types: beegfs-ssd

# %% [markdown]
# ## Summary
#
# The workflow analysis has been completed successfully. The results include:
#
# 1. **Workflow Data**: Processed datalife statistics organized in a DataFrame
# 2. **I/O Breakdown**: Time analysis for each task in the workflow
# 3. **Transfer Rate Estimates**: Estimated transfer rates for different storage configurations
# 4. **SPM Values**: Storage Performance Metrics for producer-consumer pairs
# 5. **Best Configurations**: Recommended storage and parallelism settings
# 6. **Visualizations**: Comprehensive plots and charts
# 7. **Saved Results**: CSV and JSON files for future reference
#
# ### Key Findings
#
# The analysis provides insights into:
# - Which storage types perform best for each workflow stage
# - Optimal parallelism levels for different storage configurations
# - I/O bottlenecks and performance characteristics
# - Recommendations for storage selection
#
# ### Next Steps
#
# You can:
# - Analyze different workflows by changing the `WORKFLOW_NAME` variable
# - Modify the analysis parameters in the configuration
# - Use the saved results for further analysis or comparison
# - Run the analysis programmatically using the `workflow_analysis_main.py` script
