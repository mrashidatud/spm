# %% [markdown]
# # Workflow Analysis - DDMD
#
# This notebook provides a simplified interface to the workflow analysis using modular Python scripts.
#
# ## Overview
# The analysis process includes:
# 1. Loading workflow data from datalife statistics
# 2. Estimating transfer rates using 4D interpolation from IOR benchmark data
# 3. Calculating Storage Performance Metrics (SPM) for different storage configurations
# 4. Generating visualizations and recommendations

# %%
# Import required libraries and modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os

# Import our workflow analysis modules
from modules.workflow_config import DEFAULT_WF, TEST_CONFIGS, STORAGE_LIST
from modules.workflow_data_utils import (
    load_workflow_data, calculate_io_time_breakdown
)
from modules.workflow_interpolation import (
    estimate_transfer_rates_for_workflow, calculate_aggregate_filesize_per_node
)
from modules.workflow_spm_calculator import (
    calculate_spm_for_workflow, filter_storage_options,
    display_top_sorted_averaged_rank, select_best_storage_and_parallelism
)
from modules.workflow_visualization import plot_all_visualizations

from modules.workflow_data_staging import insert_data_staging_rows

print("Modules imported successfully!")
# Out:
# Modules imported successfully!

# %% [markdown]
# ## Configuration
#
# Set the workflow to analyze and other parameters.

# %%
# Configuration
WORKFLOW_NAME = "ddmd_4n_l"  # Change this to analyze different workflows
IOR_DATA_PATH = "../perf_profiles/updated_master_ior_df.csv"

print(f"Analyzing workflow: {WORKFLOW_NAME}")
print(f"Available workflows: {list(TEST_CONFIGS.keys())}")
print(f"IOR data path: {IOR_DATA_PATH}")

ALLOWED_PARALLELISM = TEST_CONFIGS[WORKFLOW_NAME]["ALLOWED_PARALLELISM"]
# Out:
# Analyzing workflow: ddmd_4n_l
# Available workflows: ['ddmd_2n_s', 'ddmd_4n_l', '1kg', '1kg_2', 'pyflex_240f', 'pyflex_s9_48f', 'ptychonn', 'montage', 'seismology', 'llm_wf']
# IOR data path: ../perf_profiles/updated_master_ior_df.csv

# %% [markdown]
# ## Step 1: Load Workflow Data
#
# Load and process the workflow data from datalife statistics.

# %%
# Load workflow data
print("Loading workflow data...")
wf_df, task_order_dict, all_wf_dict = load_workflow_data(WORKFLOW_NAME)

print(f"\nWorkflow data loaded:")
print(f"- Total records: {len(wf_df)}")
print(f"- Task definitions: {len(task_order_dict)}")
print(f"- Unique tasks: {list(wf_df['taskName'].unique())}")
print(f"- Stages: {sorted(wf_df['stageOrder'].unique())}")
# Out:
# Loading workflow data...
# Trial folders: ['./ddmd/ddmd_4n_pfs_large/4n_pfs_t1']
# blk_files count: 89
# datalife_monitor count: 58
# target_tasks: ['143674-dlt05', '143675-dlt05', '143676-dlt05', '170276-dlt04', '170277-dlt04', '170278-dlt04', '190075-dlt02', '190099-dlt02', '190125-dlt02', '190758-dlt02', '190907-dlt02', '191338-dlt02', '74812-dlt06', '74813-dlt06', '74814-dlt06']
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0000.h5.190075-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0000.dcd.190075-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0007.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0002.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0010.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0000.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0005.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/aggregated.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/aggregated.h5.190758-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0009.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0004.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0011.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0008.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0001.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0006.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0003.h5.190758-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0011.dcd.74814-dlt06.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0011.h5.74814-dlt06.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0004.dcd.170278-dlt04.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0004.h5.170278-dlt04.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0006.dcd.143676-dlt05.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0006.h5.143676-dlt05.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0007.dcd.143674-dlt05.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0007.h5.143674-dlt05.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0010.dcd.74812-dlt06.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0010.h5.74812-dlt06.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-2-20241202-192946.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/virtual_stage0000_task0000.h5.190907-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-1-20241202-192940.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-7-20241202-193029.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/virtual_stage0000_task0000.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-4-20241202-192959.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-3-20241202-192953.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-6-20241202-193022.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-8-20241202-193035.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-5-20241202-193005.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-9-20241202-193042.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/embeddings-epoch-10-20241202-193048.h5.190907-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/virtual_stage0003_task0000.h5.191338-dlt02.local.r_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/virtual_stage0003_task0000.h5.191338-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0005.dcd.170276-dlt04.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0005.h5.170276-dlt04.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0009.dcd.74813-dlt06.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0009.h5.74813-dlt06.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0003.dcd.170277-dlt04.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0003.h5.170277-dlt04.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0002.h5.190125-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0002.dcd.190125-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0001.h5.190099-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0001.dcd.190099-dlt02.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0008.dcd.143675-dlt05.local.w_blk_trace.json
# Detected random write pattern in file: ./ddmd/ddmd_4n_pfs_large/4n_pfs_t1/stage0000_task0008.h5.143675-dlt05.local.w_blk_trace.json
# Trial folders: ['./ddmd/ddmd_4n_pfs_large/4n_pfs_t1']
# len(blk_files) = 89
# Debug: Starting prevTask assignment for read operations...
# Debug: Processing aggregate with fileName stage0000_task0007.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0007.h5
# Debug: Processing aggregate with fileName stage0000_task0002.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0002.h5
# Debug: Processing aggregate with fileName stage0000_task0010.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0010.h5
# Debug: Processing aggregate with fileName stage0000_task0000.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0000.h5
# Debug: Processing aggregate with fileName stage0000_task0005.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0005.h5
# Debug: Processing aggregate with fileName aggregated.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: No match for aggregated.h5 with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: Processing aggregate with fileName stage0000_task0009.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0009.h5
# Debug: Processing aggregate with fileName stage0000_task0004.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0004.h5
# Debug: Processing aggregate with fileName stage0000_task0011.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0011.h5
# Debug: Processing aggregate with fileName stage0000_task0008.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0008.h5
# Debug: Processing aggregate with fileName stage0000_task0001.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0001.h5
# Debug: Processing aggregate with fileName stage0000_task0006.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0006.h5
# Debug: Processing aggregate with fileName stage0000_task0003.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0003.h5
# Debug: Processing training with fileName stage0000_task0005.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0005.h5
# Debug: Processing training with fileName stage0000_task0004.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0004.h5
# Debug: Processing training with fileName stage0000_task0003.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0003.h5
# Debug: Processing training with fileName virtual_stage0000_task0000.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: No match for virtual_stage0000_task0000.h5 with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: Checking prevTask aggregate with patterns ['aggregated.h5']
# Debug: No match for virtual_stage0000_task0000.h5 with patterns ['aggregated.h5']
# Debug: Processing training with fileName embeddings-epoch-10-20241202-193048.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: No match for embeddings-epoch-10-20241202-193048.h5 with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: Checking prevTask aggregate with patterns ['aggregated.h5']
# Debug: No match for embeddings-epoch-10-20241202-193048.h5 with patterns ['aggregated.h5']
# Debug: Processing training with fileName stage0000_task0006.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0006.h5
# Debug: Processing training with fileName stage0000_task0008.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0008.h5
# Debug: Processing training with fileName stage0000_task0011.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0011.h5
# Debug: Processing training with fileName embeddings-epoch-5-20241202-193005.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: No match for embeddings-epoch-5-20241202-193005.h5 with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: Checking prevTask aggregate with patterns ['aggregated.h5']
# Debug: No match for embeddings-epoch-5-20241202-193005.h5 with patterns ['aggregated.h5']
# Debug: Processing training with fileName stage0000_task0009.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0009.h5
# Debug: Processing training with fileName stage0000_task0002.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0002.h5
# Debug: Processing training with fileName stage0000_task0007.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0007.h5
# Debug: Processing training with fileName stage0000_task0010.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0010.h5
# Debug: Processing inference with fileName stage0000_task0000.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0000.h5
# Debug: Processing inference with fileName stage0000_task0005.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0005.h5
# Debug: Processing inference with fileName stage0000_task0009.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0009.h5
# Debug: Processing inference with fileName stage0000_task0007.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0007.h5
# Debug: Processing inference with fileName stage0000_task0008.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0008.h5
# Debug: Processing inference with fileName stage0000_task0002.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0002.h5
# Debug: Processing inference with fileName stage0000_task0011.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0011.h5
# Debug: Processing inference with fileName stage0000_task0004.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0004.h5
# Debug: Processing inference with fileName virtual_stage0003_task0000.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: No match for virtual_stage0003_task0000.h5 with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: Processing inference with fileName stage0000_task0010.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0010.h5
# Debug: Processing inference with fileName stage0000_task0001.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0001.h5
# Debug: Processing inference with fileName stage0000_task0003.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0003.h5
# Debug: Processing inference with fileName stage0000_task0006.h5
# Debug: Checking prevTask openmm with patterns ['stage\\d{4}_task\\d{4}\\.h5']
# Debug: MATCH! Setting prevTask to openmm for stage0000_task0006.h5
# Expanded DataFrame shape after multi-node expansion: (267, 18)
#
# Workflow data loaded:
# - Total records: 267
# - Task definitions: 4
# - Unique tasks: ['openmm', 'aggregate', 'training', 'inference']
# - Stages: [np.int64(0), np.int64(1), np.int64(2)]
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_data_utils.py:238: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   wf_df = pd.concat([wf_df, new_row], ignore_index=True)
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_data_utils.py:253: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   folder_dfs = pd.concat([folder_dfs, wf_df], ignore_index=True)

# %%
# Display first few rows
print("\nFirst few rows of workflow data:")
print(wf_df.head())
print(wf_df.columns)
# Out:
# First few rows of workflow data:
#    operation  randomOffset  transferSize  aggregateFilesizeMB  numTasks  \
# 0          0             1   1066.397658             7.293896        12
# 1          0             1   1066.397658             7.293896        12
# 2          0             1   1066.397658             7.293896        12
# 3          0             1   1066.397658             7.293896        12
# 4          0             1   1066.397658             7.293896        12
#
#    parallelism  totalTime numNodesList  numNodes  tasksPerNode       trMiB  \
# 0           12   0.026276    [1, 2, 4]         1            12  277.589578
# 1           12   0.026276    [1, 2, 4]         2             6  277.589578
# 2           12   0.026276    [1, 2, 4]         4             3  277.589578
# 3           12   0.026276    [1, 2, 4]         1            12  277.589578
# 4           12   0.026276    [1, 2, 4]         2             6  277.589578
#
#    storageType  opCount taskName       taskPID                fileName  \
# 0            5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 1            5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 2            5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 3            5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
# 4            5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
#
#    stageOrder prevTask
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Index(['operation', 'randomOffset', 'transferSize', 'aggregateFilesizeMB',
#        'numTasks', 'parallelism', 'totalTime', 'numNodesList', 'numNodes',
#        'tasksPerNode', 'trMiB', 'storageType', 'opCount', 'taskName',
#        'taskPID', 'fileName', 'stageOrder', 'prevTask'],
#       dtype='object')

# %% [markdown]
# ## Step 2: Calculate I/O Time Breakdown
#
# Calculate the I/O time breakdown for each task in the workflow.

# %%
# Get configuration for the workflow
config = TEST_CONFIGS[WORKFLOW_NAME]
num_nodes_list = config["NUM_NODES_LIST"]

# Create task name to parallelism mapping
task_name_to_parallelism = {task: info['parallelism'] for task, info in task_order_dict.items()}

# Calculate I/O time breakdown
print("Calculating I/O time breakdown...")
io_breakdown = calculate_io_time_breakdown(wf_df, task_name_to_parallelism, num_nodes_list)

print(f"\nI/O breakdown results:")
for key, value in io_breakdown.items():
    if isinstance(value, dict):
        print(f"{key}:")
        for sub_key, sub_value in value.items():
            print(f"  {sub_key}: {sub_value:.2f} seconds")
    else:
        print(f"{key}: {value:.2f} seconds")
# Out:
# Calculating I/O time breakdown...
# Total I/O time per taskName:
#  aggregate (write): 0.10176218799999999 (sec)
#  inference (write): 2.8633e-05 (sec)
#  openmm (write): 0.05025775266666667 (sec)
#  training (write): 1.95473184 (sec)
#  aggregate (read): 2.748506033 (sec)
#  inference (read): 1.850840342 (sec)
#  training (read): 11.551488481 (sec)
# Total I/O time per workflow: 18.257615269666665
#
# I/O breakdown results:
# total_io_time: 18.26 seconds
# total_write_time: 2.11 seconds
# total_read_time: 16.15 seconds
# task_io_time_adjust:
#   read: 16.15 seconds
#   write: 2.11 seconds

# %% [markdown]
# ## Step 2.1: Calculate Aggregate File Size per Node
#
# Calculate the aggregate file size per node for proper scaling.

# %%
# Calculate aggregate file size per node
print("Calculating aggregate file size per node...")
wf_df = calculate_aggregate_filesize_per_node(wf_df)

print("\nAggregate file size calculation completed.")
print(f"Updated columns: {[col for col in wf_df.columns if 'aggregateFilesizeMB' in col]}")
# Out:
# Calculating aggregate file size per node...
#
# Aggregate file size calculation completed.
# Updated columns: ['aggregateFilesizeMBtask', 'aggregateFilesizeMB']

# %%
# Display rows with taskName include string "stage-out"
staged = insert_data_staging_rows(wf_df)
print(staged[staged['taskName'].str.startswith('stage_out-')][['taskName', 'stageOrder', 'operation']])
# Out:
#                 taskName  stageOrder operation
# 96      stage_out-openmm         0.5        cp
# 97      stage_out-openmm         0.5        cp
# 98      stage_out-openmm         0.5        cp
# 99      stage_out-openmm         0.5        cp
# 100     stage_out-openmm         0.5        cp
# ..                   ...         ...       ...
# 388  stage_out-inference         2.5        cp
# 389  stage_out-inference         2.5        cp
# 390  stage_out-inference         2.5        cp
# 391  stage_out-inference         2.5        cp
# 392  stage_out-inference         2.5        cp
#
# [90 rows x 3 columns]

# %% [markdown]
# ## Step 2.2: Insert data movement steps to workflow

# %%
# Step 2.2: Insert data staging (I/O) rows into the workflow DataFrame

# Set debug=True to see detailed output, or False for silent operation
wf_df = insert_data_staging_rows(wf_df, debug=True)

print("Data staging rows inserted. New DataFrame shape:", wf_df.shape)
display(wf_df.head(10))
# Out:
# Initial data movement: 0 rows found.
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(238.18936729431152), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-aggregate', 'taskPID': '', 'fileName': 'stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'aggregate'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_in-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_out row: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 37, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 37, 'taskName': 'stage_in-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 19, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 37, 'taskName': 'stage_in-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 10, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 37, 'taskName': 'stage_in-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 37, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 37, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 19, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 37, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added intermediate stage_out row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 10, 'trMiB': '', 'storageType': 'beegfs-ssd', 'opCount': 37, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 37, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 37, 'taskName': 'stage_in-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# Added intermediate stage_in row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(5005.108024597168), 'numTasks': 37, 'parallelism': 37, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 19, 'trMiB': '', 'storageType': 'beegfs-tmpfs', 'opCount': 37, 'taskName': 'stage_in-training', 'taskPID': '', 'fileName': 'stage0000_task0005.h5,embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,stage0000_task0004.h5,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,stage0000_task0003.h5,epoch-5-20241202-193005.pt,virtual_stage0000_task0000.h5,embeddings-epoch-10-20241202-193048.h5,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,stage0000_task0006.h5,epoch-10-20241202-193048.pt,stage0000_task0008.h5,embeddings-epoch-7-20241202-193029.h5,stage0000_task0011.h5,epoch-3-20241202-192953.pt,embeddings-epoch-5-20241202-193005.h5,stage0000_task0009.h5,virtual_stage0000_task0000.h5,stage0000_task0002.h5,stage0000_task0007.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5,stage0000_task0010.h5', 'stageOrder': np.float64(0.5), 'prevTask': 'openmm'}
# ...
# Added stage_out row for write op: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(4450.3963623046875), 'numTasks': 24, 'parallelism': 24, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 24, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 24, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,epoch-5-20241202-193005.pt,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,epoch-10-20241202-193048.pt,embeddings-epoch-7-20241202-193029.h5,epoch-3-20241202-192953.pt,virtual_stage0000_task0000.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added stage_out row for write op: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(4450.3963623046875), 'numTasks': 24, 'parallelism': 24, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 12, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 24, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,epoch-5-20241202-193005.pt,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,epoch-10-20241202-193048.pt,embeddings-epoch-7-20241202-193029.h5,epoch-3-20241202-192953.pt,virtual_stage0000_task0000.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added stage_out row for write op: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(4450.3963623046875), 'numTasks': 24, 'parallelism': 24, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 6, 'trMiB': '', 'storageType': 'ssd-ssd', 'opCount': 24, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,epoch-5-20241202-193005.pt,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,epoch-10-20241202-193048.pt,embeddings-epoch-7-20241202-193029.h5,epoch-3-20241202-192953.pt,virtual_stage0000_task0000.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added stage_out row for write op: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(4450.3963623046875), 'numTasks': 24, 'parallelism': 24, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 24, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 24, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,epoch-5-20241202-193005.pt,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,epoch-10-20241202-193048.pt,embeddings-epoch-7-20241202-193029.h5,epoch-3-20241202-192953.pt,virtual_stage0000_task0000.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added stage_out row for write op: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(4450.3963623046875), 'numTasks': 24, 'parallelism': 24, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 12, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 24, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,epoch-5-20241202-193005.pt,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,epoch-10-20241202-193048.pt,embeddings-epoch-7-20241202-193029.h5,epoch-3-20241202-192953.pt,virtual_stage0000_task0000.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Added stage_out row for write op: {'operation': 'scp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(4450.3963623046875), 'numTasks': 24, 'parallelism': 24, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 6, 'trMiB': '', 'storageType': 'tmpfs-tmpfs', 'opCount': 24, 'taskName': 'stage_out-training', 'taskPID': '', 'fileName': 'embeddings-epoch-2-20241202-192946.h5,epoch-9-20241202-193042.pt,epoch-7-20241202-193029.pt,encoder-weights.pt,discriminator-weights.pt,epoch-8-20241202-193035.pt,epoch-2-20241202-192946.pt,generator-weights.pt,epoch-5-20241202-193005.pt,embeddings-epoch-1-20241202-192940.h5,epoch-4-20241202-192959.pt,epoch-10-20241202-193048.pt,embeddings-epoch-7-20241202-193029.h5,epoch-3-20241202-192953.pt,virtual_stage0000_task0000.h5,embeddings-epoch-4-20241202-192959.h5,epoch-6-20241202-193022.pt,embeddings-epoch-3-20241202-192953.h5,embeddings-epoch-6-20241202-193022.h5,embeddings-epoch-8-20241202-193035.h5,epoch-1-20241202-192940.pt,embeddings-epoch-5-20241202-193005.h5,embeddings-epoch-9-20241202-193042.h5,embeddings-epoch-10-20241202-193048.h5', 'stageOrder': np.float64(1.5), 'prevTask': 'training'}
# Final data movement: 42 rows found for stageOrder 2.
# Added final data movement row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'tmpfs-beegfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added final data movement row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'tmpfs-beegfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added final data movement row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'tmpfs-beegfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added final data movement row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 1, 'tasksPerNode': 14, 'trMiB': '', 'storageType': 'ssd-beegfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added final data movement row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 2, 'tasksPerNode': 7, 'trMiB': '', 'storageType': 'ssd-beegfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Added final data movement row: {'operation': 'cp', 'randomOffset': 0, 'transferSize': 4096, 'aggregateFilesizeMB': np.float64(189.80823802947998), 'numTasks': 14, 'parallelism': 14, 'totalTime': '', 'numNodesList': [1, 2, 4], 'numNodes': 4, 'tasksPerNode': 4, 'trMiB': '', 'storageType': 'ssd-beegfs', 'opCount': 14, 'taskName': 'stage_out-inference', 'taskPID': '', 'fileName': 'stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5', 'stageOrder': np.float64(2.5), 'prevTask': 'inference'}
# Total rows after staging: 393
# Data staging rows inserted. New DataFrame shape: (393, 19)
#   operation  randomOffset  transferSize  aggregateFilesizeMBtask  numTasks  \
# 0         0             1   1066.397658                 7.293896        12
# 1         0             1   1066.397658                 7.293896        12
# 2         0             1   1066.397658                 7.293896        12
# 3         0             1   1066.397658                 7.293896        12
# 4         0             1   1066.397658                 7.293896        12
# 5         0             1   1066.397658                 7.293896        12
# 6         0             1   1064.135603                 7.274364        12
# 7         0             1   1064.135603                 7.274364        12
# 8         0             1   1064.135603                 7.274364        12
# 9         0             1   1064.135603                 7.274364        12
#
#    parallelism totalTime numNodesList  numNodes  tasksPerNode       trMiB  \
# 0           12  0.026276    [1, 2, 4]         1            12  277.589578
# 1           12  0.026276    [1, 2, 4]         2             6  277.589578
# 2           12  0.026276    [1, 2, 4]         4             3  277.589578
# 3           12  0.026276    [1, 2, 4]         1            12  277.589578
# 4           12  0.026276    [1, 2, 4]         2             6  277.589578
# 5           12  0.026276    [1, 2, 4]         4             3  277.589578
# 6           12  0.024391    [1, 2, 4]         1            12  298.234391
# 7           12  0.024391    [1, 2, 4]         2             6  298.234391
# 8           12  0.024391    [1, 2, 4]         4             3  298.234391
# 9           12  0.024391    [1, 2, 4]         1            12  298.234391
#
#   storageType  opCount taskName       taskPID                fileName  \
# 0           5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 1           5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 2           5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 3           5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
# 4           5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
# 5           5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
# 6           5     7168   openmm   74814-dlt06  stage0000_task0011.dcd
# 7           5     7168   openmm   74814-dlt06  stage0000_task0011.dcd
# 8           5     7168   openmm   74814-dlt06  stage0000_task0011.dcd
# 9           5     7168   openmm   74814-dlt06   stage0000_task0011.h5
#
#    stageOrder prevTask  aggregateFilesizeMB
# 0         0.0                    174.608185
# 1         0.0                     87.304092
# 2         0.0                     43.652046
# 3         0.0                    174.608185
# 4         0.0                     87.304092
# 5         0.0                     43.652046
# 6         0.0                    174.608185
# 7         0.0                     87.304092
# 8         0.0                     43.652046
# 9         0.0                    174.608185

# %%
# Check for tasks being added to stage_out
for checktask in ['inference', 'aggregate']:
    new_rows = wf_df[wf_df['taskName'] == f'stage_out-{checktask}']
    if not new_rows.empty:
        print(f"\nSample of stage_out-{checktask} rows:")
        print(new_rows[['taskName', 'fileName', 'stageOrder', 'operation']].head(3))
        print(f"Total stage_out-{checktask} rows: {len(new_rows)}")
    else:
        print(f"\nNo stage_out-{checktask} tasks found in the DataFrame")
# Out:
# Sample of stage_out-inference rows:
#                 taskName                                           fileName  \
# 363  stage_out-inference  stage0000_task0000.h5,stage0000_task0005.h5,st...
# 364  stage_out-inference  stage0000_task0000.h5,stage0000_task0005.h5,st...
# 365  stage_out-inference  stage0000_task0000.h5,stage0000_task0005.h5,st...
#
#      stageOrder operation
# 363         2.5        cp
# 364         2.5        cp
# 365         2.5        cp
# Total stage_out-inference rows: 30
#
# Sample of stage_out-aggregate rows:
#                 taskName                                           fileName  \
# 273  stage_out-aggregate  stage0000_task0007.h5,stage0000_task0002.h5,st...
# 274  stage_out-aggregate  stage0000_task0007.h5,stage0000_task0002.h5,st...
# 275  stage_out-aggregate  stage0000_task0007.h5,stage0000_task0002.h5,st...
#
#      stageOrder operation
# 273         1.5        cp
# 274         1.5        cp
# 275         1.5        cp
# Total stage_out-aggregate rows: 24

# %%
# Display first few rows
print("\nFirst few rows of workflow data:")
print(wf_df.head())
print(wf_df.columns)
print(wf_df[wf_df['operation'] == 0]['taskName'].unique())
# Out:
# First few rows of workflow data:
#   operation  randomOffset  transferSize  aggregateFilesizeMBtask  numTasks  \
# 0         0             1   1066.397658                 7.293896        12
# 1         0             1   1066.397658                 7.293896        12
# 2         0             1   1066.397658                 7.293896        12
# 3         0             1   1066.397658                 7.293896        12
# 4         0             1   1066.397658                 7.293896        12
#
#    parallelism totalTime numNodesList  numNodes  tasksPerNode       trMiB  \
# 0           12  0.026276    [1, 2, 4]         1            12  277.589578
# 1           12  0.026276    [1, 2, 4]         2             6  277.589578
# 2           12  0.026276    [1, 2, 4]         4             3  277.589578
# 3           12  0.026276    [1, 2, 4]         1            12  277.589578
# 4           12  0.026276    [1, 2, 4]         2             6  277.589578
#
#   storageType  opCount taskName       taskPID                fileName  \
# 0           5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 1           5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 2           5     7172   openmm  190075-dlt02   stage0000_task0000.h5
# 3           5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
# 4           5     7172   openmm  190075-dlt02  stage0000_task0000.dcd
#
#    stageOrder prevTask  aggregateFilesizeMB
# 0         0.0                    174.608185
# 1         0.0                     87.304092
# 2         0.0                     43.652046
# 3         0.0                    174.608185
# 4         0.0                     87.304092
# Index(['operation', 'randomOffset', 'transferSize', 'aggregateFilesizeMBtask',
#        'numTasks', 'parallelism', 'totalTime', 'numNodesList', 'numNodes',
#        'tasksPerNode', 'trMiB', 'storageType', 'opCount', 'taskName',
#        'taskPID', 'fileName', 'stageOrder', 'prevTask', 'aggregateFilesizeMB'],
#       dtype='object')
# ['openmm' 'aggregate' 'training' 'inference']

# %% [markdown]
# ## Step 3: Load IOR Benchmark Data and Estimate Transfer Rates
#
# Load the IOR benchmark data and estimate transfer rates for different storage configurations.

# %%
# Load IOR benchmark data
print("Loading IOR benchmark data...")
if os.path.exists(IOR_DATA_PATH):
    df_ior = pd.read_csv(IOR_DATA_PATH)
    print(f"Loaded {len(df_ior)} IOR benchmark records")

    # Convert operation string to integer
    df_ior['operation'] = df_ior['operation'].map({'write': 0, 'read': 1, 'cp': 2, 'scp': 3})
    # print(df_ior.head(10))

    # Estimate transfer rates
    print("\nEstimating transfer rates...")
    cp_scp_parallelism = set(wf_df.loc[wf_df['operation'].isin(['cp', 'scp']), 'parallelism'].unique())
    ALLOWED_PARALLELISM = sorted(set(ALLOWED_PARALLELISM).union(cp_scp_parallelism))

    # Then call the function:
    wf_df = estimate_transfer_rates_for_workflow(
        wf_df, df_ior, STORAGE_LIST, ALLOWED_PARALLELISM, multi_nodes=True, debug=False
    )
    # wf_df = estimate_transfer_rates_for_workflow(wf_df, df_ior, STORAGE_LIST, ALLOWED_PARALLELISM)
    print("Transfer rate estimation completed")
    
    # Show estimated transfer rate columns
    estimated_cols = [col for col in wf_df.columns if col.startswith('estimated_trMiB_')]
    print(f"\nEstimated transfer rate columns: {len(estimated_cols)}")
    print(f"Sample columns: {estimated_cols}")
else:
    print(f"Warning: IOR data file not found at {IOR_DATA_PATH}")
    print("Skipping transfer rate estimation...")
    df_ior = pd.DataFrame()

# Save the estimated transfer rates to a new CSV file
wf_df.to_csv(f"./analysis_data/{WORKFLOW_NAME}_estimated_transfer_rates.csv", index=True)
print(f"Saved estimated transfer rates to: ./analysis_data/{WORKFLOW_NAME}_estimated_transfer_rates.csv")
# Out:
# Loading IOR benchmark data...
# Loaded 21916 IOR benchmark records
#
# Estimating transfer rates...
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# Transfer rate estimation completed
#
# Estimated transfer rate columns: 58
# Sample columns: ['estimated_trMiB_localssd_12p', 'estimated_trMiB_beegfs_12p', 'estimated_trMiB_tmpfs_12p', 'estimated_trMiB_localssd_6p', 'estimated_trMiB_beegfs_6p', 'estimated_trMiB_tmpfs_6p', 'estimated_trMiB_localssd_3p', 'estimated_trMiB_beegfs_3p', 'estimated_trMiB_tmpfs_3p', 'estimated_trMiB_beegfs-ssd_14p', 'estimated_trMiB_beegfs-ssd_7p', 'estimated_trMiB_beegfs-ssd_4p', 'estimated_trMiB_beegfs-tmpfs_14p', 'estimated_trMiB_beegfs-tmpfs_7p', 'estimated_trMiB_beegfs-tmpfs_4p', 'estimated_trMiB_ssd-ssd_14p', 'estimated_trMiB_ssd-ssd_7p', 'estimated_trMiB_ssd-ssd_4p', 'estimated_trMiB_tmpfs-tmpfs_14p', 'estimated_trMiB_tmpfs-tmpfs_7p', 'estimated_trMiB_tmpfs-tmpfs_4p', 'estimated_trMiB_beegfs-ssd_37p', 'estimated_trMiB_beegfs-ssd_19p', 'estimated_trMiB_beegfs-ssd_10p', 'estimated_trMiB_beegfs-tmpfs_37p', 'estimated_trMiB_beegfs-tmpfs_19p', 'estimated_trMiB_beegfs-tmpfs_10p', 'estimated_trMiB_ssd-ssd_37p', 'estimated_trMiB_ssd-ssd_19p', 'estimated_trMiB_ssd-ssd_10p', 'estimated_trMiB_tmpfs-tmpfs_37p', 'estimated_trMiB_tmpfs-tmpfs_19p', 'estimated_trMiB_tmpfs-tmpfs_10p', 'estimated_trMiB_beegfs-ssd_24p', 'estimated_trMiB_beegfs-ssd_12p', 'estimated_trMiB_beegfs-ssd_6p', 'estimated_trMiB_beegfs-tmpfs_24p', 'estimated_trMiB_beegfs-tmpfs_12p', 'estimated_trMiB_beegfs-tmpfs_6p', 'estimated_trMiB_ssd-ssd_24p', 'estimated_trMiB_ssd-ssd_12p', 'estimated_trMiB_ssd-ssd_6p', 'estimated_trMiB_tmpfs-tmpfs_24p', 'estimated_trMiB_tmpfs-tmpfs_12p', 'estimated_trMiB_tmpfs-tmpfs_6p', 'estimated_trMiB_localssd_1p', 'estimated_trMiB_beegfs_1p', 'estimated_trMiB_tmpfs_1p', 'estimated_trMiB_beegfs-ssd_1p', 'estimated_trMiB_beegfs-tmpfs_1p', 'estimated_trMiB_ssd-ssd_1p', 'estimated_trMiB_tmpfs-tmpfs_1p', 'estimated_trMiB_tmpfs-beegfs_14p', 'estimated_trMiB_tmpfs-beegfs_7p', 'estimated_trMiB_tmpfs-beegfs_4p', 'estimated_trMiB_ssd-beegfs_14p', 'estimated_trMiB_ssd-beegfs_7p', 'estimated_trMiB_ssd-beegfs_4p']
# Saved estimated transfer rates to: ./analysis_data/ddmd_4n_l_estimated_transfer_rates.csv
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_tr_storage] = None
# /home/tang584/scripts/spm/workflow_analysis/modules/workflow_interpolation.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wf_pfs_df[col_name_ts_slope] = None

# %%
# Show all rows
pd.set_option('display.max_rows', None)
# Show all columns
pd.set_option('display.max_columns', None)
# Show full width
pd.set_option('display.width', None)
# Don't truncate column content
pd.set_option('display.max_colwidth', None)

# print(wf_df.head(10))

# Check for tasks being added to stage_out
for checktask in ['inference', 'aggregate']:
    new_rows = wf_df[wf_df['taskName'] == f'stage_out-{checktask}']
    if not new_rows.empty:
        print(f"\nSample of stage_out-{checktask} rows:")
        print(new_rows.head(3))
        print(f"Total stage_out-{checktask} rows: {len(new_rows)}")
    else:
        print(f"\nNo stage_out-{checktask} tasks found in the DataFrame")
# Out:
# Sample of stage_out-inference rows:
#     operation  randomOffset  transferSize  aggregateFilesizeMBtask  numTasks  \
# 363        cp             0        4096.0                      NaN        14
# 364        cp             0        4096.0                      NaN        14
# 365        cp             0        4096.0                      NaN        14
#
#      parallelism totalTime numNodesList  numNodes  tasksPerNode trMiB  \
# 363           14              [1, 2, 4]         1            14
# 364           14              [1, 2, 4]         2             7
# 365           14              [1, 2, 4]         4             4
#
#     storageType  opCount             taskName taskPID  \
# 363  beegfs-ssd       14  stage_out-inference
# 364  beegfs-ssd       14  stage_out-inference
# 365  beegfs-ssd       14  stage_out-inference
#
#                                                                                                                                                                                                                                                                                                                                 fileName  \
# 363  stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5
# 364  stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5
# 365  stage0000_task0000.h5,stage0000_task0005.h5,stage0000_task0009.h5,stage0000_task0007.h5,stage0000_task0008.h5,stage0000_task0002.h5,stage0000_task0011.h5,stage0000_task0004.h5,virtual_stage0003_task0000.h5,stage0000_task0010.h5,stage0000_task0001.h5,virtual_stage0003_task0000.h5,stage0000_task0003.h5,stage0000_task0006.h5
#
#      stageOrder   prevTask  aggregateFilesizeMB estimated_trMiB_localssd_12p  \
# 363         2.5  inference           189.808238                         None
# 364         2.5  inference           189.808238                         None
# 365         2.5  inference           189.808238                         None
#
#     estimated_ts_slope_localssd_12p estimated_trMiB_beegfs_12p  \
# 363                            None                       None
# 364                            None                       None
# 365                            None                       None
#
#     estimated_ts_slope_beegfs_12p estimated_trMiB_tmpfs_12p  \
# 363                          None                      None
# 364                          None                      None
# 365                          None                      None
#
#     estimated_ts_slope_tmpfs_12p estimated_trMiB_localssd_6p  \
# 363                         None                        None
# 364                         None                        None
# 365                         None                        None
#
#     estimated_ts_slope_localssd_6p estimated_trMiB_beegfs_6p  \
# 363                           None                      None
# 364                           None                      None
# 365                           None                      None
#
#     estimated_ts_slope_beegfs_6p estimated_trMiB_tmpfs_6p  \
# 363                         None                     None
# 364                         None                     None
# 365                         None                     None
#
#     estimated_ts_slope_tmpfs_6p estimated_trMiB_localssd_3p  \
# 363                        None                        None
# 364                        None                        None
# 365                        None                        None
#
#     estimated_ts_slope_localssd_3p estimated_trMiB_beegfs_3p  \
# 363                           None                      None
# 364                           None                      None
# 365                           None                      None
#
#     estimated_ts_slope_beegfs_3p estimated_trMiB_tmpfs_3p  \
# 363                         None                     None
# 364                         None                     None
# 365                         None                     None
#
#     estimated_ts_slope_tmpfs_3p estimated_trMiB_beegfs-ssd_14p  \
# 363                        None                    4943.792401
# 364                        None                           None
# 365                        None                           None
#
#     estimated_ts_slope_beegfs-ssd_14p estimated_trMiB_beegfs-ssd_7p  \
# 363                               1.0                          None
# 364                              None                    3810.37288
# 365                              None                          None
#
#     estimated_ts_slope_beegfs-ssd_7p estimated_trMiB_beegfs-ssd_4p  \
# 363                             None                          None
# 364                              1.0                          None
# 365                             None                   3782.048703
#
#     estimated_ts_slope_beegfs-ssd_4p estimated_trMiB_beegfs-tmpfs_14p  \
# 363                             None                             None
# 364                             None                             None
# 365                              1.0                             None
#
#     estimated_ts_slope_beegfs-tmpfs_14p estimated_trMiB_beegfs-tmpfs_7p  \
# 363                                None                            None
# 364                                None                            None
# 365                                None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_7p estimated_trMiB_beegfs-tmpfs_4p  \
# 363                               None                            None
# 364                               None                            None
# 365                               None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_4p estimated_trMiB_ssd-ssd_14p  \
# 363                               None                        None
# 364                               None                        None
# 365                               None                        None
#
#     estimated_ts_slope_ssd-ssd_14p estimated_trMiB_ssd-ssd_7p  \
# 363                           None                       None
# 364                           None                       None
# 365                           None                       None
#
#     estimated_ts_slope_ssd-ssd_7p estimated_trMiB_ssd-ssd_4p  \
# 363                          None                       None
# 364                          None                       None
# 365                          None                       None
#
#     estimated_ts_slope_ssd-ssd_4p estimated_trMiB_tmpfs-tmpfs_14p  \
# 363                          None                            None
# 364                          None                            None
# 365                          None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_14p estimated_trMiB_tmpfs-tmpfs_7p  \
# 363                               None                           None
# 364                               None                           None
# 365                               None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_7p estimated_trMiB_tmpfs-tmpfs_4p  \
# 363                              None                           None
# 364                              None                           None
# 365                              None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_4p estimated_trMiB_beegfs-ssd_37p  \
# 363                              None                           None
# 364                              None                           None
# 365                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_37p estimated_trMiB_beegfs-ssd_19p  \
# 363                              None                           None
# 364                              None                           None
# 365                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_19p estimated_trMiB_beegfs-ssd_10p  \
# 363                              None                           None
# 364                              None                           None
# 365                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_10p estimated_trMiB_beegfs-tmpfs_37p  \
# 363                              None                             None
# 364                              None                             None
# 365                              None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_37p estimated_trMiB_beegfs-tmpfs_19p  \
# 363                                None                             None
# 364                                None                             None
# 365                                None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_19p estimated_trMiB_beegfs-tmpfs_10p  \
# 363                                None                             None
# 364                                None                             None
# 365                                None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_10p estimated_trMiB_ssd-ssd_37p  \
# 363                                None                        None
# 364                                None                        None
# 365                                None                        None
#
#     estimated_ts_slope_ssd-ssd_37p estimated_trMiB_ssd-ssd_19p  \
# 363                           None                        None
# 364                           None                        None
# 365                           None                        None
#
#     estimated_ts_slope_ssd-ssd_19p estimated_trMiB_ssd-ssd_10p  \
# 363                           None                        None
# 364                           None                        None
# 365                           None                        None
#
#     estimated_ts_slope_ssd-ssd_10p estimated_trMiB_tmpfs-tmpfs_37p  \
# 363                           None                            None
# 364                           None                            None
# 365                           None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_37p estimated_trMiB_tmpfs-tmpfs_19p  \
# 363                               None                            None
# 364                               None                            None
# 365                               None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_19p estimated_trMiB_tmpfs-tmpfs_10p  \
# 363                               None                            None
# 364                               None                            None
# 365                               None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_10p estimated_trMiB_beegfs-ssd_24p  \
# 363                               None                           None
# 364                               None                           None
# 365                               None                           None
#
#     estimated_ts_slope_beegfs-ssd_24p estimated_trMiB_beegfs-ssd_12p  \
# 363                              None                           None
# 364                              None                           None
# 365                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_12p estimated_trMiB_beegfs-ssd_6p  \
# 363                              None                          None
# 364                              None                          None
# 365                              None                          None
#
#     estimated_ts_slope_beegfs-ssd_6p estimated_trMiB_beegfs-tmpfs_24p  \
# 363                             None                             None
# 364                             None                             None
# 365                             None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_24p estimated_trMiB_beegfs-tmpfs_12p  \
# 363                                None                             None
# 364                                None                             None
# 365                                None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_12p estimated_trMiB_beegfs-tmpfs_6p  \
# 363                                None                            None
# 364                                None                            None
# 365                                None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_6p estimated_trMiB_ssd-ssd_24p  \
# 363                               None                        None
# 364                               None                        None
# 365                               None                        None
#
#     estimated_ts_slope_ssd-ssd_24p estimated_trMiB_ssd-ssd_12p  \
# 363                           None                        None
# 364                           None                        None
# 365                           None                        None
#
#     estimated_ts_slope_ssd-ssd_12p estimated_trMiB_ssd-ssd_6p  \
# 363                           None                       None
# 364                           None                       None
# 365                           None                       None
#
#     estimated_ts_slope_ssd-ssd_6p estimated_trMiB_tmpfs-tmpfs_24p  \
# 363                          None                            None
# 364                          None                            None
# 365                          None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_24p estimated_trMiB_tmpfs-tmpfs_12p  \
# 363                               None                            None
# 364                               None                            None
# 365                               None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_12p estimated_trMiB_tmpfs-tmpfs_6p  \
# 363                               None                           None
# 364                               None                           None
# 365                               None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_6p estimated_trMiB_localssd_1p  \
# 363                              None                        None
# 364                              None                        None
# 365                              None                        None
#
#     estimated_ts_slope_localssd_1p estimated_trMiB_beegfs_1p  \
# 363                           None                      None
# 364                           None                      None
# 365                           None                      None
#
#     estimated_ts_slope_beegfs_1p estimated_trMiB_tmpfs_1p  \
# 363                         None                     None
# 364                         None                     None
# 365                         None                     None
#
#     estimated_ts_slope_tmpfs_1p estimated_trMiB_beegfs-ssd_1p  \
# 363                        None                          None
# 364                        None                          None
# 365                        None                          None
#
#     estimated_ts_slope_beegfs-ssd_1p estimated_trMiB_beegfs-tmpfs_1p  \
# 363                             None                            None
# 364                             None                            None
# 365                             None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_1p estimated_trMiB_ssd-ssd_1p  \
# 363                               None                       None
# 364                               None                       None
# 365                               None                       None
#
#     estimated_ts_slope_ssd-ssd_1p estimated_trMiB_tmpfs-tmpfs_1p  \
# 363                          None                           None
# 364                          None                           None
# 365                          None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_1p estimated_trMiB_tmpfs-beegfs_14p  \
# 363                              None                             None
# 364                              None                             None
# 365                              None                             None
#
#     estimated_ts_slope_tmpfs-beegfs_14p estimated_trMiB_tmpfs-beegfs_7p  \
# 363                                None                            None
# 364                                None                            None
# 365                                None                            None
#
#     estimated_ts_slope_tmpfs-beegfs_7p estimated_trMiB_tmpfs-beegfs_4p  \
# 363                               None                            None
# 364                               None                            None
# 365                               None                            None
#
#     estimated_ts_slope_tmpfs-beegfs_4p estimated_trMiB_ssd-beegfs_14p  \
# 363                               None                           None
# 364                               None                           None
# 365                               None                           None
#
#     estimated_ts_slope_ssd-beegfs_14p estimated_trMiB_ssd-beegfs_7p  \
# 363                              None                          None
# 364                              None                          None
# 365                              None                          None
#
#     estimated_ts_slope_ssd-beegfs_7p estimated_trMiB_ssd-beegfs_4p  \
# 363                             None                          None
# 364                             None                          None
# 365                             None                          None
#
#     estimated_ts_slope_ssd-beegfs_4p
# 363                             None
# 364                             None
# 365                             None
# Total stage_out-inference rows: 30
#
# Sample of stage_out-aggregate rows:
#     operation  randomOffset  transferSize  aggregateFilesizeMBtask  numTasks  \
# 273        cp             0        4096.0                      NaN        14
# 274        cp             0        4096.0                      NaN        14
# 275        cp             0        4096.0                      NaN        14
#
#      parallelism totalTime numNodesList  numNodes  tasksPerNode trMiB  \
# 273           14              [1, 2, 4]         1            14
# 274           14              [1, 2, 4]         2             7
# 275           14              [1, 2, 4]         4             4
#
#     storageType  opCount             taskName taskPID  \
# 273  beegfs-ssd       14  stage_out-aggregate
# 274  beegfs-ssd       14  stage_out-aggregate
# 275  beegfs-ssd       14  stage_out-aggregate
#
#                                                                                                                                                                                                                                                                                                 fileName  \
# 273  stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5
# 274  stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5
# 275  stage0000_task0007.h5,stage0000_task0002.h5,stage0000_task0010.h5,stage0000_task0000.h5,stage0000_task0005.h5,aggregated.h5,aggregated.h5,stage0000_task0009.h5,stage0000_task0004.h5,stage0000_task0011.h5,stage0000_task0008.h5,stage0000_task0001.h5,stage0000_task0006.h5,stage0000_task0003.h5
#
#      stageOrder   prevTask  aggregateFilesizeMB estimated_trMiB_localssd_12p  \
# 273         1.5  aggregate           238.189367                         None
# 274         1.5  aggregate           238.189367                         None
# 275         1.5  aggregate           238.189367                         None
#
#     estimated_ts_slope_localssd_12p estimated_trMiB_beegfs_12p  \
# 273                            None                       None
# 274                            None                       None
# 275                            None                       None
#
#     estimated_ts_slope_beegfs_12p estimated_trMiB_tmpfs_12p  \
# 273                          None                      None
# 274                          None                      None
# 275                          None                      None
#
#     estimated_ts_slope_tmpfs_12p estimated_trMiB_localssd_6p  \
# 273                         None                        None
# 274                         None                        None
# 275                         None                        None
#
#     estimated_ts_slope_localssd_6p estimated_trMiB_beegfs_6p  \
# 273                           None                      None
# 274                           None                      None
# 275                           None                      None
#
#     estimated_ts_slope_beegfs_6p estimated_trMiB_tmpfs_6p  \
# 273                         None                     None
# 274                         None                     None
# 275                         None                     None
#
#     estimated_ts_slope_tmpfs_6p estimated_trMiB_localssd_3p  \
# 273                        None                        None
# 274                        None                        None
# 275                        None                        None
#
#     estimated_ts_slope_localssd_3p estimated_trMiB_beegfs_3p  \
# 273                           None                      None
# 274                           None                      None
# 275                           None                      None
#
#     estimated_ts_slope_beegfs_3p estimated_trMiB_tmpfs_3p  \
# 273                         None                     None
# 274                         None                     None
# 275                         None                     None
#
#     estimated_ts_slope_tmpfs_3p estimated_trMiB_beegfs-ssd_14p  \
# 273                        None                    4927.895499
# 274                        None                           None
# 275                        None                           None
#
#     estimated_ts_slope_beegfs-ssd_14p estimated_trMiB_beegfs-ssd_7p  \
# 273                               1.0                          None
# 274                              None                   3799.568678
# 275                              None                          None
#
#     estimated_ts_slope_beegfs-ssd_7p estimated_trMiB_beegfs-ssd_4p  \
# 273                             None                          None
# 274                              1.0                          None
# 275                             None                   3771.370046
#
#     estimated_ts_slope_beegfs-ssd_4p estimated_trMiB_beegfs-tmpfs_14p  \
# 273                             None                             None
# 274                             None                             None
# 275                              1.0                             None
#
#     estimated_ts_slope_beegfs-tmpfs_14p estimated_trMiB_beegfs-tmpfs_7p  \
# 273                                None                            None
# 274                                None                            None
# 275                                None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_7p estimated_trMiB_beegfs-tmpfs_4p  \
# 273                               None                            None
# 274                               None                            None
# 275                               None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_4p estimated_trMiB_ssd-ssd_14p  \
# 273                               None                        None
# 274                               None                        None
# 275                               None                        None
#
#     estimated_ts_slope_ssd-ssd_14p estimated_trMiB_ssd-ssd_7p  \
# 273                           None                       None
# 274                           None                       None
# 275                           None                       None
#
#     estimated_ts_slope_ssd-ssd_7p estimated_trMiB_ssd-ssd_4p  \
# 273                          None                       None
# 274                          None                       None
# 275                          None                       None
#
#     estimated_ts_slope_ssd-ssd_4p estimated_trMiB_tmpfs-tmpfs_14p  \
# 273                          None                            None
# 274                          None                            None
# 275                          None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_14p estimated_trMiB_tmpfs-tmpfs_7p  \
# 273                               None                           None
# 274                               None                           None
# 275                               None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_7p estimated_trMiB_tmpfs-tmpfs_4p  \
# 273                              None                           None
# 274                              None                           None
# 275                              None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_4p estimated_trMiB_beegfs-ssd_37p  \
# 273                              None                           None
# 274                              None                           None
# 275                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_37p estimated_trMiB_beegfs-ssd_19p  \
# 273                              None                           None
# 274                              None                           None
# 275                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_19p estimated_trMiB_beegfs-ssd_10p  \
# 273                              None                           None
# 274                              None                           None
# 275                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_10p estimated_trMiB_beegfs-tmpfs_37p  \
# 273                              None                             None
# 274                              None                             None
# 275                              None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_37p estimated_trMiB_beegfs-tmpfs_19p  \
# 273                                None                             None
# 274                                None                             None
# 275                                None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_19p estimated_trMiB_beegfs-tmpfs_10p  \
# 273                                None                             None
# 274                                None                             None
# 275                                None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_10p estimated_trMiB_ssd-ssd_37p  \
# 273                                None                        None
# 274                                None                        None
# 275                                None                        None
#
#     estimated_ts_slope_ssd-ssd_37p estimated_trMiB_ssd-ssd_19p  \
# 273                           None                        None
# 274                           None                        None
# 275                           None                        None
#
#     estimated_ts_slope_ssd-ssd_19p estimated_trMiB_ssd-ssd_10p  \
# 273                           None                        None
# 274                           None                        None
# 275                           None                        None
#
#     estimated_ts_slope_ssd-ssd_10p estimated_trMiB_tmpfs-tmpfs_37p  \
# 273                           None                            None
# 274                           None                            None
# 275                           None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_37p estimated_trMiB_tmpfs-tmpfs_19p  \
# 273                               None                            None
# 274                               None                            None
# 275                               None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_19p estimated_trMiB_tmpfs-tmpfs_10p  \
# 273                               None                            None
# 274                               None                            None
# 275                               None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_10p estimated_trMiB_beegfs-ssd_24p  \
# 273                               None                           None
# 274                               None                           None
# 275                               None                           None
#
#     estimated_ts_slope_beegfs-ssd_24p estimated_trMiB_beegfs-ssd_12p  \
# 273                              None                           None
# 274                              None                           None
# 275                              None                           None
#
#     estimated_ts_slope_beegfs-ssd_12p estimated_trMiB_beegfs-ssd_6p  \
# 273                              None                          None
# 274                              None                          None
# 275                              None                          None
#
#     estimated_ts_slope_beegfs-ssd_6p estimated_trMiB_beegfs-tmpfs_24p  \
# 273                             None                             None
# 274                             None                             None
# 275                             None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_24p estimated_trMiB_beegfs-tmpfs_12p  \
# 273                                None                             None
# 274                                None                             None
# 275                                None                             None
#
#     estimated_ts_slope_beegfs-tmpfs_12p estimated_trMiB_beegfs-tmpfs_6p  \
# 273                                None                            None
# 274                                None                            None
# 275                                None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_6p estimated_trMiB_ssd-ssd_24p  \
# 273                               None                        None
# 274                               None                        None
# 275                               None                        None
#
#     estimated_ts_slope_ssd-ssd_24p estimated_trMiB_ssd-ssd_12p  \
# 273                           None                        None
# 274                           None                        None
# 275                           None                        None
#
#     estimated_ts_slope_ssd-ssd_12p estimated_trMiB_ssd-ssd_6p  \
# 273                           None                       None
# 274                           None                       None
# 275                           None                       None
#
#     estimated_ts_slope_ssd-ssd_6p estimated_trMiB_tmpfs-tmpfs_24p  \
# 273                          None                            None
# 274                          None                            None
# 275                          None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_24p estimated_trMiB_tmpfs-tmpfs_12p  \
# 273                               None                            None
# 274                               None                            None
# 275                               None                            None
#
#     estimated_ts_slope_tmpfs-tmpfs_12p estimated_trMiB_tmpfs-tmpfs_6p  \
# 273                               None                           None
# 274                               None                           None
# 275                               None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_6p estimated_trMiB_localssd_1p  \
# 273                              None                        None
# 274                              None                        None
# 275                              None                        None
#
#     estimated_ts_slope_localssd_1p estimated_trMiB_beegfs_1p  \
# 273                           None                      None
# 274                           None                      None
# 275                           None                      None
#
#     estimated_ts_slope_beegfs_1p estimated_trMiB_tmpfs_1p  \
# 273                         None                     None
# 274                         None                     None
# 275                         None                     None
#
#     estimated_ts_slope_tmpfs_1p estimated_trMiB_beegfs-ssd_1p  \
# 273                        None                          None
# 274                        None                          None
# 275                        None                          None
#
#     estimated_ts_slope_beegfs-ssd_1p estimated_trMiB_beegfs-tmpfs_1p  \
# 273                             None                            None
# 274                             None                            None
# 275                             None                            None
#
#     estimated_ts_slope_beegfs-tmpfs_1p estimated_trMiB_ssd-ssd_1p  \
# 273                               None                       None
# 274                               None                       None
# 275                               None                       None
#
#     estimated_ts_slope_ssd-ssd_1p estimated_trMiB_tmpfs-tmpfs_1p  \
# 273                          None                           None
# 274                          None                           None
# 275                          None                           None
#
#     estimated_ts_slope_tmpfs-tmpfs_1p estimated_trMiB_tmpfs-beegfs_14p  \
# 273                              None                             None
# 274                              None                             None
# 275                              None                             None
#
#     estimated_ts_slope_tmpfs-beegfs_14p estimated_trMiB_tmpfs-beegfs_7p  \
# 273                                None                            None
# 274                                None                            None
# 275                                None                            None
#
#     estimated_ts_slope_tmpfs-beegfs_7p estimated_trMiB_tmpfs-beegfs_4p  \
# 273                               None                            None
# 274                               None                            None
# 275                               None                            None
#
#     estimated_ts_slope_tmpfs-beegfs_4p estimated_trMiB_ssd-beegfs_14p  \
# 273                               None                           None
# 274                               None                           None
# 275                               None                           None
#
#     estimated_ts_slope_ssd-beegfs_14p estimated_trMiB_ssd-beegfs_7p  \
# 273                              None                          None
# 274                              None                          None
# 275                              None                          None
#
#     estimated_ts_slope_ssd-beegfs_7p estimated_trMiB_ssd-beegfs_4p  \
# 273                             None                          None
# 274                             None                          None
# 275                             None                          None
#
#     estimated_ts_slope_ssd-beegfs_4p
# 273                             None
# 274                             None
# 275                             None
# Total stage_out-aggregate rows: 24

# %% [markdown]
# ## Step 5: Calculate SPM Values
#
# Calculate Storage Performance Metrics (SPM) for the workflow.

# %%
# Calculate SPM values
print("Calculating SPM values...")
spm_results = calculate_spm_for_workflow(wf_df, debug=True)

print(f"\nSPM calculation completed:")
print(f"- Producer-consumer pairs: {len(spm_results)}")
for pair in spm_results.keys():
    print(f"  - {pair}")
# Out:
# Calculating SPM values...
# Stage order list: [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
# Number of nodes: 94
# First five nodes:
# ('openmm:190075-dlt02:stage0000_task0000.h5', {'operation': 0, 'randomOffset': 1, 'transferSize': 1066.3976575571667, 'aggregateFilesizeMBtask': 7.293895721435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.026275827, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 277.58957772996246, 'storageType': 5, 'opCount': 7172, 'taskName': 'openmm', 'taskPID': '190075-dlt02', 'fileName': 'stage0000_task0000.h5', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.8680534190601, 'estimated_ts_slope_localssd_12p': 0.013801320819390192, 'estimated_trMiB_beegfs_12p': 2766.6952764532625, 'estimated_ts_slope_beegfs_12p': 0.013801320819390192, 'estimated_trMiB_tmpfs_12p': 25601.408525632913, 'estimated_ts_slope_tmpfs_12p': 0.013801320819390192, 'estimated_trMiB_localssd_6p': 1028.4809555712045, 'estimated_ts_slope_localssd_6p': 0.013801320819390192, 'estimated_trMiB_beegfs_6p': 3439.764847887172, 'estimated_ts_slope_beegfs_6p': 0.013801320819390192, 'estimated_trMiB_tmpfs_6p': 16898.287461893855, 'estimated_ts_slope_tmpfs_6p': 0.013801320819390192, 'estimated_trMiB_localssd_3p': 2004.6675257498614, 'estimated_ts_slope_localssd_3p': 0.013801320819390192, 'estimated_trMiB_beegfs_3p': 4751.693795025696, 'estimated_ts_slope_beegfs_3p': 0.013801320819390192, 'estimated_trMiB_tmpfs_3p': 18193.905070007324, 'estimated_ts_slope_tmpfs_3p': 0.013801320819390192, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_ ...
# ('openmm:190075-dlt02:stage0000_task0000.dcd', {'operation': 0, 'randomOffset': 1, 'transferSize': 1066.3976575571667, 'aggregateFilesizeMBtask': 7.293895721435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.026275827, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 277.58957772996246, 'storageType': 5, 'opCount': 7172, 'taskName': 'openmm', 'taskPID': '190075-dlt02', 'fileName': 'stage0000_task0000.dcd', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.8680534190601, 'estimated_ts_slope_localssd_12p': 0.013801320819390192, 'estimated_trMiB_beegfs_12p': 2766.6952764532625, 'estimated_ts_slope_beegfs_12p': 0.013801320819390192, 'estimated_trMiB_tmpfs_12p': 25601.408525632913, 'estimated_ts_slope_tmpfs_12p': 0.013801320819390192, 'estimated_trMiB_localssd_6p': 1028.4809555712045, 'estimated_ts_slope_localssd_6p': 0.013801320819390192, 'estimated_trMiB_beegfs_6p': 3439.764847887172, 'estimated_ts_slope_beegfs_6p': 0.013801320819390192, 'estimated_trMiB_tmpfs_6p': 16898.287461893855, 'estimated_ts_slope_tmpfs_6p': 0.013801320819390192, 'estimated_trMiB_localssd_3p': 2004.6675257498614, 'estimated_ts_slope_localssd_3p': 0.013801320819390192, 'estimated_trMiB_beegfs_3p': 4751.693795025696, 'estimated_ts_slope_beegfs_3p': 0.013801320819390192, 'estimated_trMiB_tmpfs_3p': 18193.905070007324, 'estimated_ts_slope_tmpfs_3p': 0.013801320819390192, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ss ...
# ('openmm:74814-dlt06:stage0000_task0011.dcd', {'operation': 0, 'randomOffset': 1, 'transferSize': 1064.1356026785713, 'aggregateFilesizeMBtask': 7.274364471435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.024391434, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 298.2343912799693, 'storageType': 5, 'opCount': 7168, 'taskName': 'openmm', 'taskPID': '74814-dlt06', 'fileName': 'stage0000_task0011.dcd', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.779043557693, 'estimated_ts_slope_localssd_12p': 0.013064974830264106, 'estimated_trMiB_beegfs_12p': 2766.533367671658, 'estimated_ts_slope_beegfs_12p': 0.013064974830264106, 'estimated_trMiB_tmpfs_12p': 25598.521064286448, 'estimated_ts_slope_tmpfs_12p': 0.013064974830264106, 'estimated_trMiB_localssd_6p': 1028.3961699564968, 'estimated_ts_slope_localssd_6p': 0.013064974830264106, 'estimated_trMiB_beegfs_6p': 3439.5747231786645, 'estimated_ts_slope_beegfs_6p': 0.013064974830264106, 'estimated_trMiB_tmpfs_6p': 16896.208198187138, 'estimated_ts_slope_tmpfs_6p': 0.013064974830264106, 'estimated_trMiB_localssd_3p': 2004.4998460299155, 'estimated_ts_slope_localssd_3p': 0.013064974830264106, 'estimated_trMiB_beegfs_3p': 4751.5405899503285, 'estimated_ts_slope_beegfs_3p': 0.013064974830264106, 'estimated_trMiB_tmpfs_3p': 18191.426045347114, 'estimated_ts_slope_tmpfs_3p': 0.013064974830264106, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_2 ...
# ('openmm:74814-dlt06:stage0000_task0011.h5', {'operation': 0, 'randomOffset': 1, 'transferSize': 1064.1356026785713, 'aggregateFilesizeMBtask': 7.274364471435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.024391434, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 298.2343912799693, 'storageType': 5, 'opCount': 7168, 'taskName': 'openmm', 'taskPID': '74814-dlt06', 'fileName': 'stage0000_task0011.h5', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.779043557693, 'estimated_ts_slope_localssd_12p': 0.013064974830264106, 'estimated_trMiB_beegfs_12p': 2766.533367671658, 'estimated_ts_slope_beegfs_12p': 0.013064974830264106, 'estimated_trMiB_tmpfs_12p': 25598.521064286448, 'estimated_ts_slope_tmpfs_12p': 0.013064974830264106, 'estimated_trMiB_localssd_6p': 1028.3961699564968, 'estimated_ts_slope_localssd_6p': 0.013064974830264106, 'estimated_trMiB_beegfs_6p': 3439.5747231786645, 'estimated_ts_slope_beegfs_6p': 0.013064974830264106, 'estimated_trMiB_tmpfs_6p': 16896.208198187138, 'estimated_ts_slope_tmpfs_6p': 0.013064974830264106, 'estimated_trMiB_localssd_3p': 2004.4998460299155, 'estimated_ts_slope_localssd_3p': 0.013064974830264106, 'estimated_trMiB_beegfs_3p': 4751.5405899503285, 'estimated_ts_slope_beegfs_3p': 0.013064974830264106, 'estimated_trMiB_tmpfs_3p': 18191.426045347114, 'estimated_ts_slope_tmpfs_3p': 0.013064974830264106, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_24p ...
# ('openmm:170278-dlt04:stage0000_task0004.dcd', {'operation': 0, 'randomOffset': 1, 'transferSize': 1066.6951185495118, 'aggregateFilesizeMBtask': 7.293895721435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.025835182, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 282.324147026932, 'storageType': 5, 'opCount': 7170, 'taskName': 'openmm', 'taskPID': '170278-dlt04', 'fileName': 'stage0000_task0004.dcd', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.8797582463574, 'estimated_ts_slope_localssd_12p': 0.013898150569502535, 'estimated_trMiB_beegfs_12p': 2766.716567513573, 'estimated_ts_slope_beegfs_12p': 0.013898150569502535, 'estimated_trMiB_tmpfs_12p': 25601.788227790275, 'estimated_ts_slope_tmpfs_12p': 0.013898150569502535, 'estimated_trMiB_localssd_6p': 1028.4921049086172, 'estimated_ts_slope_localssd_6p': 0.013898150569502535, 'estimated_trMiB_beegfs_6p': 3439.789849351547, 'estimated_ts_slope_beegfs_6p': 0.013898150569502535, 'estimated_trMiB_tmpfs_6p': 16898.560885784405, 'estimated_ts_slope_tmpfs_6p': 0.013898150569502535, 'estimated_trMiB_localssd_3p': 2004.6895756905428, 'estimated_ts_slope_localssd_3p': 0.013898150569502535, 'estimated_trMiB_beegfs_3p': 4751.71394154565, 'estimated_ts_slope_beegfs_3p': 0.013898150569502535, 'estimated_trMiB_tmpfs_3p': 18194.231062600367, 'estimated_ts_slope_tmpfs_3p': 0.013898150569502535, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_24 ...
# Stage order list: [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
# Number of nodes: 94
# First five nodes:
# (openmm:190075-dlt02:stage0000_task0000.h5, {'operation': 0, 'randomOffset': 1, 'transferSize': 1066.3976575571667, 'aggregateFilesizeMBtask': 7.293895721435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.026275827, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 277.58957772996246, 'storageType': 5, 'opCount': 7172, 'taskName': 'openmm', 'taskPID': '190075-dlt02', 'fileName': 'stage0000_task0000.h5', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.8680534190601, 'estimated_ts_slope_localssd_12p': 0.013801320819390192, 'estimated_trMiB_beegfs_12p': 2766.6952764532625, 'estimated_ts_slope_beegfs_12p': 0.013801320819390192, 'estimated_trMiB_tmpfs_12p': 25601.408525632913, 'estimated_ts_slope_tmpfs_12p': 0.013801320819390192, 'estimated_trMiB_localssd_6p': 1028.4809555712045, 'estimated_ts_slope_localssd_6p': 0.013801320819390192, 'estimated_trMiB_beegfs_6p': 3439.764847887172, 'estimated_ts_slope_beegfs_6p': 0.013801320819390192, 'estimated_trMiB_tmpfs_6p': 16898.287461893855, 'estimated_ts_slope_tmpfs_6p': 0.013801320819390192, 'estimated_trMiB_localssd_3p': 2004.6675257498614, 'estimated_ts_slope_localssd_3p': 0.013801320819390192, 'estimated_trMiB_beegfs_3p': 4751.693795025696, 'estimated_ts_slope_beegfs_3p': 0.013801320819390192, 'estimated_trMiB_tmpfs_3p': 18193.905070007324, 'estimated_ts_slope_tmpfs_3p': 0.013801320819390192, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_24 ...
# (openmm:190075-dlt02:stage0000_task0000.dcd, {'operation': 0, 'randomOffset': 1, 'transferSize': 1066.3976575571667, 'aggregateFilesizeMBtask': 7.293895721435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.026275827, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 277.58957772996246, 'storageType': 5, 'opCount': 7172, 'taskName': 'openmm', 'taskPID': '190075-dlt02', 'fileName': 'stage0000_task0000.dcd', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.8680534190601, 'estimated_ts_slope_localssd_12p': 0.013801320819390192, 'estimated_trMiB_beegfs_12p': 2766.6952764532625, 'estimated_ts_slope_beegfs_12p': 0.013801320819390192, 'estimated_trMiB_tmpfs_12p': 25601.408525632913, 'estimated_ts_slope_tmpfs_12p': 0.013801320819390192, 'estimated_trMiB_localssd_6p': 1028.4809555712045, 'estimated_ts_slope_localssd_6p': 0.013801320819390192, 'estimated_trMiB_beegfs_6p': 3439.764847887172, 'estimated_ts_slope_beegfs_6p': 0.013801320819390192, 'estimated_trMiB_tmpfs_6p': 16898.287461893855, 'estimated_ts_slope_tmpfs_6p': 0.013801320819390192, 'estimated_trMiB_localssd_3p': 2004.6675257498614, 'estimated_ts_slope_localssd_3p': 0.013801320819390192, 'estimated_trMiB_beegfs_3p': 4751.693795025696, 'estimated_ts_slope_beegfs_3p': 0.013801320819390192, 'estimated_trMiB_tmpfs_3p': 18193.905070007324, 'estimated_ts_slope_tmpfs_3p': 0.013801320819390192, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_ ...
# (openmm:74814-dlt06:stage0000_task0011.dcd, {'operation': 0, 'randomOffset': 1, 'transferSize': 1064.1356026785713, 'aggregateFilesizeMBtask': 7.274364471435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.024391434, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 298.2343912799693, 'storageType': 5, 'opCount': 7168, 'taskName': 'openmm', 'taskPID': '74814-dlt06', 'fileName': 'stage0000_task0011.dcd', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.779043557693, 'estimated_ts_slope_localssd_12p': 0.013064974830264106, 'estimated_trMiB_beegfs_12p': 2766.533367671658, 'estimated_ts_slope_beegfs_12p': 0.013064974830264106, 'estimated_trMiB_tmpfs_12p': 25598.521064286448, 'estimated_ts_slope_tmpfs_12p': 0.013064974830264106, 'estimated_trMiB_localssd_6p': 1028.3961699564968, 'estimated_ts_slope_localssd_6p': 0.013064974830264106, 'estimated_trMiB_beegfs_6p': 3439.5747231786645, 'estimated_ts_slope_beegfs_6p': 0.013064974830264106, 'estimated_trMiB_tmpfs_6p': 16896.208198187138, 'estimated_ts_slope_tmpfs_6p': 0.013064974830264106, 'estimated_trMiB_localssd_3p': 2004.4998460299155, 'estimated_ts_slope_localssd_3p': 0.013064974830264106, 'estimated_trMiB_beegfs_3p': 4751.5405899503285, 'estimated_ts_slope_beegfs_3p': 0.013064974830264106, 'estimated_trMiB_tmpfs_3p': 18191.426045347114, 'estimated_ts_slope_tmpfs_3p': 0.013064974830264106, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_24p ...
# (openmm:74814-dlt06:stage0000_task0011.h5, {'operation': 0, 'randomOffset': 1, 'transferSize': 1064.1356026785713, 'aggregateFilesizeMBtask': 7.274364471435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.024391434, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 298.2343912799693, 'storageType': 5, 'opCount': 7168, 'taskName': 'openmm', 'taskPID': '74814-dlt06', 'fileName': 'stage0000_task0011.h5', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.779043557693, 'estimated_ts_slope_localssd_12p': 0.013064974830264106, 'estimated_trMiB_beegfs_12p': 2766.533367671658, 'estimated_ts_slope_beegfs_12p': 0.013064974830264106, 'estimated_trMiB_tmpfs_12p': 25598.521064286448, 'estimated_ts_slope_tmpfs_12p': 0.013064974830264106, 'estimated_trMiB_localssd_6p': 1028.3961699564968, 'estimated_ts_slope_localssd_6p': 0.013064974830264106, 'estimated_trMiB_beegfs_6p': 3439.5747231786645, 'estimated_ts_slope_beegfs_6p': 0.013064974830264106, 'estimated_trMiB_tmpfs_6p': 16896.208198187138, 'estimated_ts_slope_tmpfs_6p': 0.013064974830264106, 'estimated_trMiB_localssd_3p': 2004.4998460299155, 'estimated_ts_slope_localssd_3p': 0.013064974830264106, 'estimated_trMiB_beegfs_3p': 4751.5405899503285, 'estimated_ts_slope_beegfs_3p': 0.013064974830264106, 'estimated_trMiB_tmpfs_3p': 18191.426045347114, 'estimated_ts_slope_tmpfs_3p': 0.013064974830264106, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_24p': ...
# (openmm:170278-dlt04:stage0000_task0004.dcd, {'operation': 0, 'randomOffset': 1, 'transferSize': 1066.6951185495118, 'aggregateFilesizeMBtask': 7.293895721435547, 'numTasks': 12, 'parallelism': 12, 'totalTime': 0.025835182, 'numNodesList': '[1, 2, 4]', 'numNodes': 1, 'tasksPerNode': 12, 'trMiB': 282.324147026932, 'storageType': 5, 'opCount': 7170, 'taskName': 'openmm', 'taskPID': '170278-dlt04', 'fileName': 'stage0000_task0004.dcd', 'stageOrder': 0.0, 'prevTask': '', 'aggregateFilesizeMB': 174.60818481445312, 'estimated_trMiB_localssd_12p': 908.8797582463574, 'estimated_ts_slope_localssd_12p': 0.013898150569502535, 'estimated_trMiB_beegfs_12p': 2766.716567513573, 'estimated_ts_slope_beegfs_12p': 0.013898150569502535, 'estimated_trMiB_tmpfs_12p': 25601.788227790275, 'estimated_ts_slope_tmpfs_12p': 0.013898150569502535, 'estimated_trMiB_localssd_6p': 1028.4921049086172, 'estimated_ts_slope_localssd_6p': 0.013898150569502535, 'estimated_trMiB_beegfs_6p': 3439.789849351547, 'estimated_ts_slope_beegfs_6p': 0.013898150569502535, 'estimated_trMiB_tmpfs_6p': 16898.560885784405, 'estimated_ts_slope_tmpfs_6p': 0.013898150569502535, 'estimated_trMiB_localssd_3p': 2004.6895756905428, 'estimated_ts_slope_localssd_3p': 0.013898150569502535, 'estimated_trMiB_beegfs_3p': 4751.71394154565, 'estimated_ts_slope_beegfs_3p': 0.013898150569502535, 'estimated_trMiB_tmpfs_3p': 18194.231062600367, 'estimated_ts_slope_tmpfs_3p': 0.013898150569502535, 'estimated_trMiB_beegfs-ssd_14p': None, 'estimated_ts_slope_beegfs-ssd_14p': None, 'estimated_trMiB_beegfs-ssd_7p': None, 'estimated_ts_slope_beegfs-ssd_7p': None, 'estimated_trMiB_beegfs-ssd_4p': None, 'estimated_ts_slope_beegfs-ssd_4p': None, 'estimated_trMiB_beegfs-tmpfs_14p': None, 'estimated_ts_slope_beegfs-tmpfs_14p': None, 'estimated_trMiB_beegfs-tmpfs_7p': None, 'estimated_ts_slope_beegfs-tmpfs_7p': None, 'estimated_trMiB_beegfs-tmpfs_4p': None, 'estimated_ts_slope_beegfs-tmpfs_4p': None, 'estimated_trMiB_ssd-ssd_14p': None, 'estimated_ts_slope_ssd-ssd_14p': None, 'estimated_trMiB_ssd-ssd_7p': None, 'estimated_ts_slope_ssd-ssd_7p': None, 'estimated_trMiB_ssd-ssd_4p': None, 'estimated_ts_slope_ssd-ssd_4p': None, 'estimated_trMiB_tmpfs-tmpfs_14p': None, 'estimated_ts_slope_tmpfs-tmpfs_14p': None, 'estimated_trMiB_tmpfs-tmpfs_7p': None, 'estimated_ts_slope_tmpfs-tmpfs_7p': None, 'estimated_trMiB_tmpfs-tmpfs_4p': None, 'estimated_ts_slope_tmpfs-tmpfs_4p': None, 'estimated_trMiB_beegfs-ssd_37p': None, 'estimated_ts_slope_beegfs-ssd_37p': None, 'estimated_trMiB_beegfs-ssd_19p': None, 'estimated_ts_slope_beegfs-ssd_19p': None, 'estimated_trMiB_beegfs-ssd_10p': None, 'estimated_ts_slope_beegfs-ssd_10p': None, 'estimated_trMiB_beegfs-tmpfs_37p': None, 'estimated_ts_slope_beegfs-tmpfs_37p': None, 'estimated_trMiB_beegfs-tmpfs_19p': None, 'estimated_ts_slope_beegfs-tmpfs_19p': None, 'estimated_trMiB_beegfs-tmpfs_10p': None, 'estimated_ts_slope_beegfs-tmpfs_10p': None, 'estimated_trMiB_ssd-ssd_37p': None, 'estimated_ts_slope_ssd-ssd_37p': None, 'estimated_trMiB_ssd-ssd_19p': None, 'estimated_ts_slope_ssd-ssd_19p': None, 'estimated_trMiB_ssd-ssd_10p': None, 'estimated_ts_slope_ssd-ssd_10p': None, 'estimated_trMiB_tmpfs-tmpfs_37p': None, 'estimated_ts_slope_tmpfs-tmpfs_37p': None, 'estimated_trMiB_tmpfs-tmpfs_19p': None, 'estimated_ts_slope_tmpfs-tmpfs_19p': None, 'estimated_trMiB_tmpfs-tmpfs_10p': None, 'estimated_ts_slope_tmpfs-tmpfs_10p': None, 'estimated_trMiB_beegfs-ssd_24p': None, 'estimated_ts_slope_beegfs-ssd_24p': None, 'estimated_trMiB_beegfs-ssd_12p': None, 'estimated_ts_slope_beegfs-ssd_12p': None, 'estimated_trMiB_beegfs-ssd_6p': None, 'estimated_ts_slope_beegfs-ssd_6p': None, 'estimated_trMiB_beegfs-tmpfs_24p': None, 'estimated_ts_slope_beegfs-tmpfs_24p': None, 'estimated_trMiB_beegfs-tmpfs_12p': None, 'estimated_ts_slope_beegfs-tmpfs_12p': None, 'estimated_trMiB_beegfs-tmpfs_6p': None, 'estimated_ts_slope_beegfs-tmpfs_6p': None, 'estimated_trMiB_ssd-ssd_24p': None, 'estimated_ts_slope_ssd-ssd_24p' ...
#
# Found 4 stage_out tasks:
#   Stage 0.5: stage_out-openmm -> 12 nodes
#   Stage 1.5: stage_out-aggregate -> 24 nodes
#   Stage 1.5: stage_out-training -> 24 nodes
#   Stage 2.5: stage_out-inference -> 30 nodes
#
# === Processing producer-consumer edges ===
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# Found regular task -> stage_out connection: openmm -> stage_out-openmm
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for aggregate at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for training at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for training at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for training at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for training at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for training at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# DEBUG: Looking for training at stage 1.5, available tasks: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training']
# ...
#   Pair 155: ['training'] -> ['stage_out-training']
#   Pair 156: ['training'] -> ['stage_out-training']
#   Pair 157: ['training'] -> ['stage_out-training']
#   Pair 158: ['training'] -> ['stage_out-training']
#   Pair 159: ['training'] -> ['stage_out-training']
#   Pair 160: ['training'] -> ['stage_out-training']
#   Pair 161: ['training'] -> ['stage_out-training']
#   Pair 162: ['training'] -> ['stage_out-training']
#   Pair 163: ['training'] -> ['stage_out-training']
#   Pair 164: ['training'] -> ['stage_out-training']
#   Pair 165: ['training'] -> ['stage_out-training']
#   Pair 166: ['training'] -> ['stage_out-training']
#   Pair 167: ['training'] -> ['stage_out-training']
#   Pair 168: ['training'] -> ['stage_out-training']
#   Pair 169: ['training'] -> ['stage_out-training']
#   Pair 170: ['training'] -> ['stage_out-training']
#   Pair 171: ['training'] -> ['stage_out-training']
#   Pair 172: ['training'] -> ['stage_out-training']
#   Pair 173: ['training'] -> ['stage_out-training']
#   Pair 174: ['training'] -> ['stage_out-training']
#   Pair 175: ['training'] -> ['stage_out-training']
#   Pair 176: ['training'] -> ['stage_out-training']
#   Pair 177: ['training'] -> ['stage_out-training']
#   Pair 178: ['training'] -> ['stage_out-training']
#   Pair 179: ['training'] -> ['stage_out-training']
#   Pair 180: ['training'] -> ['stage_out-training']
#   Pair 181: ['training'] -> ['stage_out-training']
#   Pair 182: ['training'] -> ['stage_out-training']
#   Pair 183: ['training'] -> ['stage_out-training']
#   Pair 184: ['training'] -> ['stage_out-training']
#   Pair 185: ['training'] -> ['stage_out-training']
#   Pair 186: ['training'] -> ['stage_out-training']
#   Pair 187: ['training'] -> ['stage_out-training']
#   Pair 188: ['training'] -> ['stage_out-training']
#   Pair 189: ['training'] -> ['stage_out-training']
#   Pair 190: ['training'] -> ['stage_out-training']
#   Pair 191: ['training'] -> ['stage_out-training']
#   Pair 192: ['training'] -> ['stage_out-training']
#   Pair 193: ['training'] -> ['stage_out-training']
#   Pair 194: ['training'] -> ['stage_out-training']
#   Pair 195: ['training'] -> ['stage_out-training']
#   Pair 196: ['training'] -> ['stage_out-training']
#   Pair 197: ['training'] -> ['stage_out-training']
#   Pair 198: ['training'] -> ['stage_out-training']
#   Pair 199: ['training'] -> ['stage_out-training']
#   Pair 200: ['training'] -> ['stage_out-training']
#   Pair 201: ['training'] -> ['stage_out-training']
#   Pair 202: ['training'] -> ['stage_out-training']
#   Pair 203: ['training'] -> ['stage_out-training']
#   Pair 204: ['training'] -> ['stage_out-training']
#   Pair 205: ['training'] -> ['stage_out-training']
#   Pair 206: ['training'] -> ['stage_out-training']
#   Pair 207: ['training'] -> ['stage_out-training']
#   Pair 208: ['training'] -> ['stage_out-training']
#   Pair 209: ['training'] -> ['stage_out-training']
#   Pair 210: ['training'] -> ['stage_out-training']
#   Pair 211: ['training'] -> ['stage_out-training']
#   Pair 212: ['training'] -> ['stage_out-training']
#   Pair 213: ['training'] -> ['stage_out-training']
#   Pair 214: ['training'] -> ['stage_out-training']
#   Pair 215: ['training'] -> ['stage_out-training']
#   Pair 216: ['training'] -> ['stage_out-training']
#   Pair 217: ['training'] -> ['stage_out-training']
#   Pair 218: ['training'] -> ['stage_out-training']
#   Pair 219: ['training'] -> ['stage_out-training']
#   Pair 220: ['training'] -> ['stage_out-training']
#   Pair 221: ['training'] -> ['stage_out-training']
#   Pair 222: ['training'] -> ['stage_out-training']
#   Pair 223: ['training'] -> ['stage_out-training']
#   Pair 224: ['training'] -> ['stage_out-training']
#   Pair 225: ['training'] -> ['stage_out-training']
#   Pair 226: ['training'] -> ['stage_out-training']
#   Pair 227: ['training'] -> ['stage_out-training']
#   Pair 228: ['training'] -> ['stage_out-training']
#   Pair 229: ['training'] -> ['stage_out-training']
#   Pair 230: ['training'] -> ['stage_out-training']
#   Pair 231: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 232: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 233: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 234: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 235: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 236: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 237: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 238: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 239: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 240: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 241: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 242: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 243: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 244: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 245: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 246: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 247: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 248: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 249: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 250: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 251: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 252: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 253: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 254: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-aggregate']
#   Pair 255: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 256: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 257: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 258: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 259: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 260: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 261: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 262: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 263: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 264: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 265: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 266: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 267: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 268: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 269: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 270: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 271: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 272: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 273: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 274: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 275: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 276: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 277: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 278: ['stage_in-aggregate', 'stage_in-training', 'stage_out-openmm'] -> ['stage_out-training']
#   Pair 279: ['inference'] -> ['stage_out-inference']
#   Pair 280: ['inference'] -> ['stage_out-inference']
#   Pair 281: ['inference'] -> ['stage_out-inference']
#   Pair 282: ['inference'] -> ['stage_out-inference']
#   Pair 283: ['inference'] -> ['stage_out-inference']
#   Pair 284: ['inference'] -> ['stage_out-inference']
#   Pair 285: ['inference'] -> ['stage_out-inference']
#   Pair 286: ['inference'] -> ['stage_out-inference']
#   Pair 287: ['inference'] -> ['stage_out-inference']
#   Pair 288: ['inference'] -> ['stage_out-inference']
#   Pair 289: ['inference'] -> ['stage_out-inference']
#   Pair 290: ['inference'] -> ['stage_out-inference']
#   Pair 291: ['inference'] -> ['stage_out-inference']
#   Pair 292: ['inference'] -> ['stage_out-inference']
#   Pair 293: ['inference'] -> ['stage_out-inference']
#   Pair 294: ['inference'] -> ['stage_out-inference']
#   Pair 295: ['inference'] -> ['stage_out-inference']
#   Pair 296: ['inference'] -> ['stage_out-inference']
#   Pair 297: ['inference'] -> ['stage_out-inference']
#   Pair 298: ['inference'] -> ['stage_out-inference']
#   Pair 299: ['inference'] -> ['stage_out-inference']
#   Pair 300: ['inference'] -> ['stage_out-inference']
#   Pair 301: ['inference'] -> ['stage_out-inference']
#   Pair 302: ['inference'] -> ['stage_out-inference']
#   Pair 303: ['inference'] -> ['stage_out-inference']
#   Pair 304: ['inference'] -> ['stage_out-inference']
#   Pair 305: ['inference'] -> ['stage_out-inference']
#   Pair 306: ['inference'] -> ['stage_out-inference']
#   Pair 307: ['inference'] -> ['stage_out-inference']
#   Pair 308: ['inference'] -> ['stage_out-inference']
#   Pair 309: ['inference'] -> ['stage_out-inference']
#   Pair 310: ['inference'] -> ['stage_out-inference']
#   Pair 311: ['inference'] -> ['stage_out-inference']
#   Pair 312: ['inference'] -> ['stage_out-inference']
#   Pair 313: ['inference'] -> ['stage_out-inference']
#   Pair 314: ['inference'] -> ['stage_out-inference']
#   Pair 315: ['inference'] -> ['stage_out-inference']
#   Pair 316: ['inference'] -> ['stage_out-inference']
#   Pair 317: ['inference'] -> ['stage_out-inference']
#   Pair 318: ['inference'] -> ['stage_out-inference']
#   Pair 319: ['inference'] -> ['stage_out-inference']
#   Pair 320: ['inference'] -> ['stage_out-inference']
#   Pair 321: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 322: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 323: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 324: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 325: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 326: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 327: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 328: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 329: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 330: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 331: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 332: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 333: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 334: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 335: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 336: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 337: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 338: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 339: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 340: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 341: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 342: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 343: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 344: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 345: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 346: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 347: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 348: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 349: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#   Pair 350: ['stage_in-inference', 'stage_out-aggregate', 'stage_out-training'] -> ['stage_out-inference']
#
# === Processing producer-consumer edges ===
# Producers: 87 nodes
# Consumers: 91 nodes
# Producer tasks: ['aggregate', 'inference', 'openmm', 'stage_in-aggregate', 'stage_in-inference', 'stage_in-training', 'training']
# Consumer tasks: ['aggregate', 'inference', 'openmm', 'stage_out-aggregate', 'stage_out-inference', 'stage_out-openmm', 'stage_out-training', 'training']
# ✓ Found both aggregate and stage_out-aggregate
# ✓ Found both inference and stage_out-inference
# Processing pair: aggregate -> consumers with prevTask=aggregate
# Processing pair: inference -> consumers with prevTask=inference
# Processing pair: openmm -> consumers with prevTask=openmm
# Processing stage_in connection: stage_in-aggregate -> aggregate
# Processing stage_in connection: stage_in-inference -> inference
# Processing stage_in connection: stage_in-training -> training
# Processing pair: training -> consumers with prevTask=training
# Processed 204 pairs, created 2115 edge attributes, total edges: 147
# Processed pairs: ['aggregate:stage_out-aggregate', 'inference:stage_out-inference', 'openmm:stage_out-openmm', 'openmm:aggregate', 'openmm:inference', 'openmm:training', 'stage_in-aggregate:aggregate', 'stage_in-inference:inference', 'stage_in-training:training', 'training:stage_out-training']
# Calculating averages and ranks for 10 producer-consumer pairs...
# Completed averaging and ranking calculations.
#
# SPM calculation completed:
# - Producer-consumer pairs: 10
#   - openmm:stage_out-openmm
#   - openmm:aggregate
#   - openmm:inference
#   - openmm:training
#   - stage_in-aggregate:aggregate
#   - stage_in-training:training
#   - aggregate:stage_out-aggregate
#   - training:stage_out-training
#   - stage_in-inference:inference
#   - inference:stage_out-inference

# %%
# # printe all spm results with producer : consumer pairs

# # Print weighted SPM values for debugging
# for pair, data in spm_results.items():
#     print(f"\nProducer-Consumer Pair: {pair}")
#     print("SPM:")
#     for storage_n, spm_values in data['SPM'].items():
#         print(f"  {storage_n}: {spm_values[0:10]} ...")
#     print("estT_prod:")
#     for storage_n, estT_prod_values in data['estT_prod'].items():
#         print(f"  {storage_n}: {estT_prod_values[0:10]} ...")
#     print("estT_cons:")
#     for storage_n, estT_cons_values in data['estT_cons'].items():
#         print(f"  {storage_n}: {estT_cons_values[0:10]} ...")
#     print("dsize_prod:")
#     for storage_n, dsize_prod_values in data['dsize_prod'].items():
#         print(f"  {storage_n}: {dsize_prod_values[0:10]} ...")
#     print("dsize_cons:")
#     for storage_n, dsize_cons_values in data['dsize_cons'].items():
#         print(f"  {storage_n}: {dsize_cons_values[0:10]} ...")

# %% [markdown]
# ## Step 6: Filter Storage Options and Select Best Configuration
#
# Filter storage options and select the best storage configuration for each producer-consumer pair.

# %%
# Filter storage options
print("Filtering storage options...")
filtered_spm_results = filter_storage_options(spm_results, WORKFLOW_NAME)

# Select best storage and parallelism
print("\nSelecting best storage and parallelism...")
best_results = select_best_storage_and_parallelism(spm_results, baseline=0)

print("\nBest storage configurations:")
for pair, config in best_results.items():
    print(f"{pair}:")
    print(f"  Best storage: {config['best_storage_type']}")
    print(f"  Best parallelism: {config['best_parallelism']}")
    print(f"  Best rank: {config['best_rank']:.2f}")
# Out:
# Filtering storage options...
#
# Selecting best storage and parallelism...
# Selecting best storage configurations for 10 pairs...
# Selected best storage configurations for 10 pairs.
#
# Best storage configurations:
# openmm:stage_out-openmm:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_12_24p
#   Best rank: 0.77
# openmm:aggregate:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_12_1p
#   Best rank: 14467.22
# openmm:inference:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_12_1p
#   Best rank: 18113.89
# openmm:training:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_12_1p
#   Best rank: 48.88
# stage_in-aggregate:aggregate:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_14_1p
#   Best rank: 14418.33
# stage_in-training:training:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_37_1p
#   Best rank: 0.00
# aggregate:stage_out-aggregate:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_1_1p
#   Best rank: 0.01
# training:stage_out-training:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_1_24p
#   Best rank: 26.28
# stage_in-inference:inference:
#   Best storage: tmpfs
#   Best parallelism: tmpfs_14_1p
#   Best rank: 18065.00
# inference:stage_out-inference:
#   Best storage: beegfs-ssd
#   Best parallelism: beegfs-ssd_1_1p
#   Best rank: 0.00

# %% [markdown]
# ## Step 7: Display Top Results
#
# Display the top storage configurations based on rank values.

# %%
# Display top results
print("Displaying top results...")
display_top_sorted_averaged_rank(spm_results, top_n=20)
# Out:
# Displaying top results...
# Top 20 Averaged SPM Values Closest to Baseline = 0:
#
# Producer: openmm, Consumer: stage_out-openmm
# - Rank 1: beegfs-ssd_12_24p with Averaged rank = 0.7714285268133748
# - Rank 2: beegfs-ssd_6_24p with Averaged rank = 0.7714285268133748
# - Rank 3: beegfs-ssd_3_24p with Averaged rank = 0.7714285268133748
# - Rank 4: beegfs-ssd_12_12p with Averaged rank = 0.8008579032661048
# - Rank 5: beegfs-ssd_6_12p with Averaged rank = 0.8008579032661048
# - Rank 6: beegfs-ssd_3_12p with Averaged rank = 0.8008579032661048
# - Rank 7: beegfs-ssd_12_6p with Averaged rank = 0.8328524434130604
# - Rank 8: beegfs-ssd_6_6p with Averaged rank = 0.8328524434130604
# - Rank 9: beegfs-ssd_3_6p with Averaged rank = 0.8328524434130604
# - Rank 10: beegfs-tmpfs_12_6p with Averaged rank = 1.1039801233045914
# - Rank 11: beegfs-tmpfs_6_6p with Averaged rank = 1.1039801233045914
# - Rank 12: beegfs-tmpfs_3_6p with Averaged rank = 1.1039801233045914
# - Rank 13: beegfs-tmpfs_12_12p with Averaged rank = 9.56555576402249
# - Rank 14: beegfs-tmpfs_6_12p with Averaged rank = 9.56555576402249
# - Rank 15: beegfs-tmpfs_3_12p with Averaged rank = 9.56555576402249
# - Rank 16: beegfs-tmpfs_12_24p with Averaged rank = 12.766358653733109
# - Rank 17: beegfs-tmpfs_6_24p with Averaged rank = 12.766358653733109
# - Rank 18: beegfs-tmpfs_3_24p with Averaged rank = 12.766358653733109
# - Rank 19: tmpfs-tmpfs_12_6p with Averaged rank = 40.63544773053355
# - Rank 20: tmpfs-tmpfs_6_6p with Averaged rank = 40.63544773053355
#
# Producer: openmm, Consumer: aggregate
# - Rank 1: tmpfs_12_1p with Averaged rank = 14467.217079146452
# - Rank 2: tmpfs_3_1p with Averaged rank = 14487.12287347761
# - Rank 3: tmpfs_6_1p with Averaged rank = 14492.396523353691
# - Rank 4: localssd_3_1p with Averaged rank = 15636.835761442062
# - Rank 5: localssd_6_1p with Averaged rank = 16229.417011942136
# - Rank 6: localssd_12_1p with Averaged rank = 16389.589091939284
# - Rank 7: beegfs_3_1p with Averaged rank = 42052.60924226965
# - Rank 8: beegfs_6_1p with Averaged rank = 42153.07086275436
# - Rank 9: beegfs_12_1p with Averaged rank = 42241.586490818714
#
# Producer: openmm, Consumer: inference
# - Rank 1: tmpfs_12_1p with Averaged rank = 18113.890035206587
# - Rank 2: tmpfs_3_1p with Averaged rank = 18133.795829537743
# - Rank 3: tmpfs_6_1p with Averaged rank = 18139.069479413825
# - Rank 4: localssd_3_1p with Averaged rank = 19285.333649414057
# - Rank 5: localssd_6_1p with Averaged rank = 19877.91489991413
# - Rank 6: localssd_12_1p with Averaged rank = 20038.08697991128
# - Rank 7: beegfs_3_1p with Averaged rank = 51765.74010953565
# - Rank 8: beegfs_6_1p with Averaged rank = 51866.20173002035
# - Rank 9: beegfs_12_1p with Averaged rank = 51954.71735808471
#
# Producer: openmm, Consumer: training
# - Rank 1: tmpfs_12_1p with Averaged rank = 48.8826108508546
# - Rank 2: tmpfs_3_1p with Averaged rank = 68.78650309327885
# - Rank 3: tmpfs_6_1p with Averaged rank = 74.05941973989
# - Rank 4: beegfs_3_1p with Averaged rank = 263.3493603184871
# - Rank 5: beegfs_6_1p with Averaged rank = 363.79997551787534
# - Rank 6: beegfs_12_1p with Averaged rank = 452.3052142277512
# - Rank 7: localssd_3_1p with Averaged rank = 624.2553015999249
# - Rank 8: localssd_6_1p with Averaged rank = 1216.767983685717
# - Rank 9: localssd_12_1p with Averaged rank = 1376.9253818172665
#
# Producer: stage_in-aggregate, Consumer: aggregate
# - Rank 1: tmpfs_14_1p with Averaged rank = 14418.32909880697
# - Rank 2: tmpfs_7_1p with Averaged rank = 14418.32909880697
# - Rank 3: tmpfs_4_1p with Averaged rank = 14418.32909880697
#
# Producer: stage_in-training, Consumer: training
# - Rank 1: tmpfs_37_1p with Averaged rank = 1.1034277188168507e-05
# - Rank 2: tmpfs_19_1p with Averaged rank = 1.1034277188168507e-05
# - Rank 3: tmpfs_10_1p with Averaged rank = 1.1034277188168507e-05
#
# Producer: aggregate, Consumer: stage_out-aggregate
# - Rank 1: beegfs-ssd_1_1p with Averaged rank = 0.01276624287337648
# - Rank 2: beegfs-tmpfs_1_1p with Averaged rank = 0.03350133482295572
# - Rank 3: tmpfs-tmpfs_1_1p with Averaged rank = 0.15938161550391772
# - Rank 4: beegfs-ssd_1_14p with Averaged rank = 0.6766886884080349
# - Rank 5: beegfs-ssd_1_7p with Averaged rank = 0.8776393914120438
# - Rank 6: beegfs-ssd_1_4p with Averaged rank = 0.8842015238934088
# - Rank 7: beegfs-tmpfs_1_4p with Averaged rank = 1.0619947287246947
# - Rank 8: beegfs-tmpfs_1_14p with Averaged rank = 6.70013030463213
# - Rank 9: beegfs-tmpfs_1_7p with Averaged rank = 9.298310614697925
# - Rank 10: tmpfs-tmpfs_1_4p with Averaged rank = 32.05527693075571
# - Rank 11: tmpfs-tmpfs_1_7p with Averaged rank = 32.97065753661184
# - Rank 12: tmpfs-tmpfs_1_14p with Averaged rank = 33.62359549139909
#
# Producer: training, Consumer: stage_out-training
# - Rank 1: beegfs-ssd_1_24p with Averaged rank = 26.28424454276403
# - Rank 2: beegfs-ssd_1_12p with Averaged rank = 27.90428034945751
# - Rank 3: beegfs-ssd_1_6p with Averaged rank = 28.606264210281704
# - Rank 4: beegfs-tmpfs_1_6p with Averaged rank = 36.969868684702526
# - Rank 5: beegfs-ssd_1_10p with Averaged rank = 46.67659556651322
# - Rank 6: beegfs-ssd_1_19p with Averaged rank = 47.11285509868528
# - Rank 7: beegfs-ssd_1_37p with Averaged rank = 49.92828046554615
# - Rank 8: beegfs-tmpfs_1_10p with Averaged rank = 66.51501038349443
# - Rank 9: beegfs-tmpfs_1_12p with Averaged rank = 384.3224424745274
# - Rank 10: beegfs-tmpfs_1_24p with Averaged rank = 435.47563974335566
# - Rank 11: beegfs-tmpfs_1_37p with Averaged rank = 557.7182514307799
# - Rank 12: beegfs-tmpfs_1_19p with Averaged rank = 748.3616970251095
# - Rank 13: tmpfs-tmpfs_1_6p with Averaged rank = 1018.3431363325375
# - Rank 14: tmpfs-tmpfs_1_12p with Averaged rank = 1045.6443821047103
# - Rank 15: tmpfs-tmpfs_1_24p with Averaged rank = 1120.042039919383
# - Rank 16: tmpfs-tmpfs_1_10p with Averaged rank = 1778.1819172133125
# - Rank 17: tmpfs-tmpfs_1_19p with Averaged rank = 1884.5361579463809
# - Rank 18: tmpfs-tmpfs_1_37p with Averaged rank = 1996.3997115105462
#
# Producer: stage_in-inference, Consumer: inference
# - Rank 1: tmpfs_14_1p with Averaged rank = 18065.002054867102
# - Rank 2: tmpfs_7_1p with Averaged rank = 18065.002054867102
# - Rank 3: tmpfs_4_1p with Averaged rank = 18065.002054867102
#
# Producer: inference, Consumer: stage_out-inference
# - Rank 1: beegfs-ssd_1_1p with Averaged rank = 1.362326233812605e-05
# - Rank 2: beegfs-tmpfs_1_1p with Averaged rank = 3.577486094534376e-05
# - Rank 3: tmpfs-tmpfs_1_1p with Averaged rank = 0.00017028871961020264
# - Rank 4: beegfs-ssd_1_14p with Averaged rank = 0.5375054445763502
# - Rank 5: beegfs-ssd_1_7p with Averaged rank = 0.6973898398731524
# - Rank 6: beegfs-ssd_1_4p with Averaged rank = 0.7026126687764426
# - Rank 7: tmpfs-beegfs_1_4p with Averaged rank = 0.8425604961066787
# - Rank 8: beegfs-tmpfs_1_4p with Averaged rank = 0.8440473975057444
# - Rank 9: beegfs-tmpfs_1_14p with Averaged rank = 5.319824318782819
# - Rank 10: beegfs-tmpfs_1_7p with Averaged rank = 7.378543224592281
# - Rank 11: tmpfs-beegfs_1_7p with Averaged rank = 12.10879981033838
# - Rank 12: tmpfs-beegfs_1_14p with Averaged rank = 15.848433563596503
# - Rank 13: tmpfs-tmpfs_1_4p with Averaged rank = 25.550624574595304
# - Rank 14: tmpfs-tmpfs_1_7p with Averaged rank = 26.278814336627878
# - Rank 15: tmpfs-tmpfs_1_14p with Averaged rank = 26.80051337031222

# %% [markdown]
# ## Step 8: Generate Visualizations
#
# Generate comprehensive visualizations of the analysis results.

# %%
# # Generate visualizations
# print("Generating visualizations...")
# plot_all_visualizations(wf_df, best_results, io_breakdown['task_io_time_adjust'])
# print("Visualizations completed!")

# %% [markdown]
# ## Step 9: Save Results
#
# Save the analysis results to files for future reference.

# %%
#FIXME Step 9: Debug and save filtered SPM results
import os
import pandas as pd
import numpy as np
from modules.workflow_results_exporter import extract_producer_consumer_results, print_storage_analysis

# Debug: Check what's in filtered_spm_results
print("=== Debugging filtered_spm_results ===")
print(f"Type: {type(filtered_spm_results)}")
print(f"Length: {len(filtered_spm_results) if filtered_spm_results else 'None/Empty'}")

if filtered_spm_results:
    print(f"Keys: {list(filtered_spm_results.keys())[:5]}...")  # First 5 keys
    
    # Examine first item structure
    first_key = list(filtered_spm_results.keys())[0]
    first_value = filtered_spm_results[first_key]
    print(f"\nFirst item - Key: '{first_key}'")
    print(f"  Type: {type(first_value)}")
    if isinstance(first_value, dict):
        print(f"  Keys: {list(first_value.keys())}")
        for k, v in first_value.items():
            print(f"    {k}: {type(v)} = {v}")

# Try to extract results
print("\n=== Attempting to Extract Results ===")
try:
    results_df = extract_producer_consumer_results(filtered_spm_results, wf_df)
    print(f"Extracted {len(results_df)} rows")
    
    if not results_df.empty:
        print("Sample data:")
        print(results_df.head())
        
        # Save to CSV
        output_dir = "workflow_spm_results"
        os.makedirs(output_dir, exist_ok=True)
        workflow_name = "ddmd_4n_l"  # or your workflow name
        csv_filename = f"{workflow_name}_filtered_spm_results.csv"
        csv_path = os.path.join(output_dir, csv_filename)
        
        results_df.to_csv(csv_path, index=False)
        print(f"✓ Saved to: {csv_path}")
        
        # Print storage analysis
        print_storage_analysis(results_df)
        
    else:
        print("Error: Extracted DataFrame is empty - trying alternative method...")
        
        # Alternative extraction method
        results_data = []
        for pair, data in filtered_spm_results.items():
            if isinstance(data, dict):
                # Try to find storage and SPM information
                storage_info = None
                spm_value = None
                
                # Look for storage-related keys
                for key in data.keys():
                    if 'storage' in key.lower() or 'type' in key.lower():
                        storage_info = data[key]
                    if 'spm' in key.lower() or 'rank' in key.lower():
                        spm_value = data[key]
                
                if storage_info:
                    producer, consumer = pair.split(':') if ':' in pair else ('unknown', 'unknown')
                    results_data.append({
                        'producer': producer,
                        'producerStage': -1,
                        'consumer': consumer,
                        'consumerStage': -1,
                        'prodParallelism': np.nan,
                        'consParallelism': np.nan,
                        'p-c-Storage': storage_info,
                        'p-c-SPM': spm_value if spm_value else np.nan
                    })
        
        if results_data:
            alt_df = pd.DataFrame(results_data)
            
            # Fill stage information
            task_stage_mapping = {}
            for _, row in wf_df.iterrows():
                task_name = row['taskName']
                stage_order = row['stageOrder']
                if task_name not in task_stage_mapping:
                    task_stage_mapping[task_name] = stage_order
            
            for i, row in alt_df.iterrows():
                if row['producer'] in task_stage_mapping:
                    alt_df.at[i, 'producerStage'] = task_stage_mapping[row['producer']]
                if row['consumer'] in task_stage_mapping:
                    alt_df.at[i, 'consumerStage'] = task_stage_mapping[row['consumer']]
            
            # Save alternative results
            output_dir = "workflow_spm_results"
            os.makedirs(output_dir, exist_ok=True)
            workflow_name = "ddmd_4n_l"
            csv_filename = f"{workflow_name}_filtered_spm_results_alt.csv"
            csv_path = os.path.join(output_dir, csv_filename)
            
            alt_df.to_csv(csv_path, index=False)
            print(f"✓ Saved alternative results to: {csv_path}")
            print(f"Alternative DataFrame shape: {alt_df.shape}")
            print(alt_df.head())
        else:
            print("Error: No data could be extracted with alternative method")
            
except Exception as e:
    print(f"Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# === Debugging filtered_spm_results ===
# Type: <class 'dict'>
# Length: 10
# Keys: ['openmm:stage_out-openmm', 'openmm:aggregate', 'openmm:inference', 'openmm:training', 'stage_in-aggregate:aggregate']...
#
# First item - Key: 'openmm:stage_out-openmm'
#   Type: <class 'dict'>
#   Keys: ['SPM', 'estT_prod', 'estT_cons', 'rank', 'par_prod', 'par_cons', 'dsize_prod', 'dsize_cons']
#     SPM: <class 'dict'> = {'tmpfs-tmpfs_12_24p': [1.0820220628717518], 'tmpfs-tmpfs_12_12p': [1.166640952211367], 'tmpfs-tmpfs_12_6p': [1.2030870353312026], 'tmpfs-tmpfs_6_24p': [1.639310663748498], 'tmpfs-tmpfs_6_12p': [1.7675119753565294], 'tmpfs-tmpfs_6_6p': [1.8227293824319826], 'tmpfs-tmpfs_3_24p': [1.5225906544914878], 'tmpfs-tmpfs_3_12p': [1.6416639474703747], 'tmpfs-tmpfs_3_6p': [1.692949838447313], 'beegfs-tmpfs_12_24p': [35.43370223126123], 'beegfs-tmpfs_12_12p': [47.290441065145096], 'beegfs-tmpfs_12_6p': [409.7531663521236], 'beegfs-tmpfs_6_24p': [28.500195938260955], 'beegfs-tmpfs_6_12p': [38.036861843195645], 'beegfs-tmpfs_6_6p': [329.574523461888], 'beegfs-tmpfs_3_24p': [20.63094964732033], 'beegfs-tmpfs_3_12p': [27.534427592322487], 'beegfs-tmpfs_3_6p': [238.57504044222011], 'beegfs-ssd_12_24p': [586.3917853575819], 'beegfs-ssd_12_12p': [564.8434625781006], 'beegfs-ssd_12_6p': [543.1446526831071], 'beegfs-ssd_6_24p': [471.6492978973394], 'beegfs-ssd_6_12p': [454.3174532781143], 'beegfs-ssd_6_6p': [436.8645681802431], 'beegfs-ssd_3_24p': [341.4212638114145], 'beegfs-ssd_3_12p': [328.8749495892593], 'beegfs-ssd_3_6p': [316.2410156179049]}
#     estT_prod: <class 'dict'> = {'tmpfs_12p': [48.914882954015084, 48.914882954015084, 48.89311634866855, 48.89311634866855, 48.90051718186896, 48.90051718186896, 48.85258887701206, 48.85258887701206, 48.88153685323348, 48.88153685323348, 48.87574717081962, 48.87574717081962, 48.90051718186896, 48.90051718186896, 48.89890616164783, 48.89890616164783, 48.91627586138124, 48.91627586138124, 48.90630725787072, 48.90630725787072, 48.914882954015084, 48.914882954015084, 48.80048527140263, 48.80048527140263], 'tmpfs_6p': [74.1075037522713, 74.1075037522713, 74.07528683768754, 74.07528683768754, 74.0856392198936, 74.0856392198936, 74.01488125997622, 74.01488125997622, 74.05802770840282, 74.05802770840282, 74.04939826152255, 74.04939826152255, 74.0856392198936, 74.0856392198936, 74.08391652001545, 74.08391652001545, 74.10980603728264, 74.10980603728264, 74.09426937651557, 74.09426937651557, 74.1075037522713, 74.1075037522713, 73.93722261493807, 73.93722261493807], 'tmpfs_3p': [68.8301877288378, 68.8301877288378, 68.80117400527398, 68.80117400527398, 68.8097606770032, 68.8097606770032, 68.74625958654954, 68.74625958654954, 68.78548372396246, 68.78548372396246, 68.77763871743515, 68.77763871743515, 68.8097606770032, 68.8097606770032, 68.80901927996972, 68.80901927996972, 68.83255563968629, 68.83255563968629, 68.8176064918888, 68.8176064918888, 68.8301877288378, 68.8301877288378, 68.67566179124424, 68.67566179124424], 'beegfs_12p': [452.63022355487533, 452.63022355487533, 452.4042555840748, 452.4042555840748, 452.50051986522726, 452.50051986522726, 451.9971123662874, 451.9971123662874, 452.2879284079193, 452.2879284079193, 452.22976498249415, 452.22976498249415, 452.50051986522726, 452.50051986522726, 452.4624193347072, 452.4624193347072, 452.6369112362368, 452.6369112362368, 452.55868427107623, 452.55868427107623, 452.63022355487533, 452.63022355487533, 451.4736503433683, 451.4736503433683], 'beegfs_6p': [364.0626487181121, 364.0626487181121, 363.8797146390669, 363.8797146390669, 363.9584800087828, 363.9584800087828, 363.5506920779604, 363.5506920779604, 363.7857078037864, 363.7857078037864, 363.73870450285114, 363.73870450285114, 363.9584800087828, 363.9584800087828, 363.92671817334224, 363.92671817334224, 364.06772924228915, 364.06772924228915, 364.00548401318747, 364.00548401318747, 364.0626487181121, 364.0626487181121, 363.12766868781137, 363.12766868781137], 'beegfs_3p': [263.54600180681166, 263.54600180681166, 263.4075085872483, 263.4075085872483, 263.47139169585495, 263.47139169585495, 263.16139180172274, 263.16139180172274, 263.33718940979753, 263.33718940979753, 263.302029849817, 263.302029849817, 263.47139169585495, 263.47139169585495, 263.4426682047018, 263.4426682047018, 263.54814717187463, 263.54814717187463, 263.50655142911074, 263.50655142911074, 263.54600180681166, 263.54600180681166, 262.84495731799524, 262.84495731799524], 'tmpfs-tmpfs_12p': [0.0], 'tmpfs-tmpfs_6p': [0.0], 'tmpfs-tmpfs_3p': [0.0], 'beegfs-tmpfs_12p': [0.0], 'beegfs-tmpfs_6p': [0.0], 'beegfs-tmpfs_3p': [0.0], 'beegfs-ssd_12p': [0.0], 'beegfs-ssd_6p': [0.0], 'beegfs-ssd_3p': [0.0]}
#     estT_cons: <class 'dict'> = {'tmpfs-tmpfs_24p': [45.18205498484202], 'tmpfs-tmpfs_12p': [41.90490677257345], 'tmpfs-tmpfs_6p': [40.63544773053355], 'beegfs-tmpfs_24p': [12.766358653733109], 'beegfs-tmpfs_12p': [9.56555576402249], 'beegfs-tmpfs_6p': [1.1039801233045914], 'beegfs-ssd_24p': [0.7714285268133748], 'beegfs-ssd_12p': [0.8008579032661048], 'beegfs-ssd_6p': [0.8328524434130604]}
#     rank: <class 'dict'> = {'tmpfs-tmpfs_12_24p': [45.18205498484202], 'tmpfs-tmpfs_12_12p': [41.90490677257345], 'tmpfs-tmpfs_12_6p': [40.63544773053355], 'tmpfs-tmpfs_6_24p': [45.18205498484202], 'tmpfs-tmpfs_6_12p': [41.90490677257345], 'tmpfs-tmpfs_6_6p': [40.63544773053355], 'tmpfs-tmpfs_3_24p': [45.18205498484202], 'tmpfs-tmpfs_3_12p': [41.90490677257345], 'tmpfs-tmpfs_3_6p': [40.63544773053355], 'beegfs-tmpfs_12_24p': [12.766358653733109], 'beegfs-tmpfs_12_12p': [9.56555576402249], 'beegfs-tmpfs_12_6p': [1.1039801233045914], 'beegfs-tmpfs_6_24p': [12.766358653733109], 'beegfs-tmpfs_6_12p': [9.56555576402249], 'beegfs-tmpfs_6_6p': [1.1039801233045914], 'beegfs-tmpfs_3_24p': [12.766358653733109], 'beegfs-tmpfs_3_12p': [9.56555576402249], 'beegfs-tmpfs_3_6p': [1.1039801233045914], 'beegfs-ssd_12_24p': [0.7714285268133748], 'beegfs-ssd_12_12p': [0.8008579032661048], 'beegfs-ssd_12_6p': [0.8328524434130604], 'beegfs-ssd_6_24p': [0.7714285268133748], 'beegfs-ssd_6_12p': [0.8008579032661048], 'beegfs-ssd_6_6p': [0.8328524434130604], 'beegfs-ssd_3_24p': [0.7714285268133748], 'beegfs-ssd_3_12p': [0.8008579032661048], 'beegfs-ssd_3_6p': [0.8328524434130604]}
#     par_prod: <class 'dict'> = {'prod_max_parallelism': [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]}
#     par_cons: <class 'dict'> = {'cons_max_parallelism': [24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24]}
#     dsize_prod: <class 'dict'> = {'prod_aggregateFilesizeMB': [174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312], 'tmpfs-tmpfs_12_24p': [0], 'tmpfs-tmpfs_12_12p': [0], 'tmpfs-tmpfs_12_6p': [0], 'tmpfs-tmpfs_6_24p': [0], 'tmpfs-tmpfs_6_12p': [0], 'tmpfs-tmpfs_6_6p': [0], 'tmpfs-tmpfs_3_24p': [0], 'tmpfs-tmpfs_3_12p': [0], 'tmpfs-tmpfs_3_6p': [0], 'beegfs-tmpfs_12_24p': [0], 'beegfs-tmpfs_12_12p': [0], 'beegfs-tmpfs_12_6p': [0], 'beegfs-tmpfs_6_24p': [0], 'beegfs-tmpfs_6_12p': [0], 'beegfs-tmpfs_6_6p': [0], 'beegfs-tmpfs_3_24p': [0], 'beegfs-tmpfs_3_12p': [0], 'beegfs-tmpfs_3_6p': [0], 'beegfs-ssd_12_24p': [0], 'beegfs-ssd_12_12p': [0], 'beegfs-ssd_12_6p': [0], 'beegfs-ssd_6_24p': [0], 'beegfs-ssd_6_12p': [0], 'beegfs-ssd_6_6p': [0], 'beegfs-ssd_3_24p': [0], 'beegfs-ssd_3_12p': [0], 'beegfs-ssd_3_6p': [0]}
#     dsize_cons: <class 'dict'> = {'cons_aggregateFilesizeMB': [174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312, 174.60818481445312], 'tmpfs-tmpfs_12_24p': [0], 'tmpfs-tmpfs_12_12p': [0], 'tmpfs-tmpfs_12_6p': [0], 'tmpfs-tmpfs_6_24p': [0], 'tmpfs-tmpfs_6_12p': [0], 'tmpfs-tmpfs_6_6p': [0], 'tmpfs-tmpfs_3_24p': [0], 'tmpfs-tmpfs_3_12p': [0], 'tmpfs-tmpfs_3_6p': [0], 'beegfs-tmpfs_12_24p': [0], 'beegfs-tmpfs_12_12p': [0], 'beegfs-tmpfs_12_6p': [0], 'beegfs-tmpfs_6_24p': [0], 'beegfs-tmpfs_6_12p': [0], 'beegfs-tmpfs_6_6p': [0], 'beegfs-tmpfs_3_24p': [0], 'beegfs-tmpfs_3_12p': [0], 'beegfs-tmpfs_3_6p': [0], 'beegfs-ssd_12_24p': [0], 'beegfs-ssd_12_12p': [0], 'beegfs-ssd_12_6p': [0], 'beegfs-ssd_6_24p': [0], 'beegfs-ssd_6_12p': [0], 'beegfs-ssd_6_6p': [0], 'beegfs-ssd_3_24p': [0], 'beegfs-ssd_3_12p': [0], 'beegfs-ssd_3_6p': [0]}
#
# === Attempting to Extract Results ===
# Extracted 10 rows
# Sample data:
#              producer  producerStage          consumer  consumerStage  \
# 0              openmm            0.0  stage_out-openmm            0.5
# 1              openmm            0.0         aggregate            1.0
# 3              openmm            0.0          training            1.0
# 2              openmm            0.0         inference            2.0
# 4  stage_in-aggregate            0.5         aggregate            1.0
#
#   prodParallelism consParallelism p-c-Storage       p-c-SPM
# 0              12             24p  beegfs-ssd      0.771429
# 1              12              1p       tmpfs  14467.217079
# 3              12              1p       tmpfs     48.882611
# 2              12              1p       tmpfs  18113.890035
# 4              14              1p       tmpfs  14418.329099
# ✓ Saved to: workflow_spm_results/ddmd_4n_l_filtered_spm_results.csv
#
# === Storage Distribution Analysis ===
#
# Storage Type Usage:
#   tmpfs: 6 pairs (60.0%)
#   beegfs-ssd: 4 pairs (40.0%)
#
# SPM Performance by Storage Type:
#   beegfs-ssd:
#     Mean SPM: 6.7671
#     Min SPM: 0.0000
#     Max SPM: 26.2842
#     Std Dev: 13.0164
#   tmpfs:
#     Mean SPM: 10852.2201
#     Min SPM: 0.0000
#     Max SPM: 18113.8900
#     Std Dev: 8544.2869
#
# Stage-wise Analysis:
#   Stage 0.0:
#     Pairs: 4
#     Avg SPM: 8157.6903
#     Storage types: beegfs-ssd, tmpfs
#   Stage 0.5:
#     Pairs: 2
#     Avg SPM: 7209.1646
#     Storage types: tmpfs
#   Stage 1.0:
#     Pairs: 2
#     Avg SPM: 13.1485
#     Storage types: beegfs-ssd
#   Stage 1.5:
#     Pairs: 1
#     Avg SPM: 18065.0021
#     Storage types: tmpfs
#   Stage 2.0:
#     Pairs: 1
#     Avg SPM: 0.0000
#     Storage types: beegfs-ssd

# %% [markdown]
# ## Summary
#
# The workflow analysis has been completed successfully. The results include:
#
# 1. **Workflow Data**: Processed datalife statistics organized in a DataFrame
# 2. **I/O Breakdown**: Time analysis for each task in the workflow
# 3. **Transfer Rate Estimates**: Estimated transfer rates for different storage configurations
# 4. **SPM Values**: Storage Performance Metrics for producer-consumer pairs
# 5. **Best Configurations**: Recommended storage and parallelism settings
# 6. **Visualizations**: Comprehensive plots and charts
# 7. **Saved Results**: CSV and JSON files for future reference
#
# ### Key Findings
#
# The analysis provides insights into:
# - Which storage types perform best for each workflow stage
# - Optimal parallelism levels for different storage configurations
# - I/O bottlenecks and performance characteristics
# - Recommendations for storage selection
#
# ### Next Steps
#
# You can:
# - Analyze different workflows by changing the `WORKFLOW_NAME` variable
# - Modify the analysis parameters in the configuration
# - Use the saved results for further analysis or comparison
# - Run the analysis programmatically using the `workflow_analysis_main.py` script
